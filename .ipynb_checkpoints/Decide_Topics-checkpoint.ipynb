# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm
tqdm.pandas()
from bs4 import BeautifulSoup

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer

# %%
#Gensim Test
#import matplotlib.pyplot as plt
import gensim
import numpy as np

import spacy
import textacy
nlp = spacy.load('en_core_web_sm')
en = textacy.load_spacy_lang("en_core_web_sm")

from gensim.models import CoherenceModel, LdaModel, LsiModel, HdpModel
from gensim.models.wrappers import LdaMallet
from gensim.corpora import Dictionary
import pyLDAvis.gensim



import os, re, operator, warnings
warnings.filterwarnings('ignore')  # Let's not pay heed to them right now
# %matplotlib inline

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.metrics.pairwise import cosine_similarity

# %%
df_sp = pd.read_csv('spacified.csv')

# %%
texts = []
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
en_stop = set(stopwords.words('english'))
for i in df_sp['spacified']:
    
    # clean and tokenize document string
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)

    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if (not i in en_stop and not str(i).isdigit() and len(str(i)) > 2 )]
    
    # stem tokens
    #stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
    
    # add tokens to list
    texts.append(stopped_tokens)

# %%
texts
# Out:
# [['would',
#   'love',
#   'think',
#   'kind',
#   'intellectual',
#   'either',
#   'dumbest',
#   'smart',
#   'guy',
#   'smartest',
#   'dumb',
#   'guy',
#   'say',
#   'ican',
#   'tell',
#   'difference',
#   'love',
#   'talk',
#   'ideas',
#   'concepts',
#   'iforge',
#   'odd',
#   'metaphors',
#   'instead',
#   'reciting',
#   'cliches',
#   'like',
#   'thesimularities',
#   'friend',
#   'mine',
#   'house',
#   'underwatersalt',
#   'mine',
#   'favorite',
#   'word',
#   'salt',
#   'way',
#   'weird',
#   'choice',
#   'iknow',
#   'things',
#   'life',
#   'better',
#   'metaphors',
#   'seek',
#   'tomake',
#   'little',
#   'better',
#   'everyday',
#   'productively',
#   'lazyway',
#   'got',
#   'tired',
#   'tying',
#   'shoes',
#   'considered',
#   'hiring',
#   'five',
#   'yearold',
#   'would',
#   'probably',
#   'tie',
#   'shoes',
#   'decided',
#   'toonly',
#   'wear',
#   'leather',
#   'shoes',
#   'dress',
#   'shoes',
#   'love',
#   'really',
#   'serious',
#   'really',
#   'deep',
#   'conversations',
#   'aboutreally',
#   'silly',
#   'stuff',
#   'willing',
#   'snap',
#   'alight',
#   'hearted',
#   'rant',
#   'kiss',
#   'funny',
#   'youhave',
#   'able',
#   'make',
#   'laugh',
#   'able',
#   'bend',
#   'spoonswith',
#   'mind',
#   'telepathically',
#   'make',
#   'smile',
#   'stillat',
#   'work',
#   'love',
#   'life',
#   'cool',
#   'letting',
#   'thewind',
#   'blow',
#   'extra',
#   'points',
#   'reading',
#   'guessing',
#   'myfavorite',
#   'video',
#   'game',
#   'hints',
#   'given',
#   'yet',
#   'lastly',
#   'agood',
#   'attention',
#   'span'],
#  ['work', 'library', 'school'],
#  ['australian',
#   'living',
#   'san',
#   'francisco',
#   'hold',
#   'thatagainst',
#   'spend',
#   'days',
#   'trying',
#   'build',
#   'cool',
#   'stuff',
#   'formy',
#   'company',
#   'speak',
#   'mandarin',
#   'known',
#   'bust',
#   'outchinese',
#   'songs',
#   'karaoke',
#   'pretty',
#   'cheeky',
#   'someone',
#   'asked',
#   'ifthat',
#   'meant',
#   'something',
#   'arse',
#   'find',
#   'reallyfunny',
#   'little',
#   'oddball',
#   'wild',
#   'imagination',
#   'like',
#   'think',
#   'ofthe',
#   'improbable',
#   'reasons',
#   'people',
#   'things',
#   'fun',
#   'ilove',
#   'laugh',
#   'look',
#   'reasons',
#   'occasionally',
#   'getsme',
#   'trouble',
#   'people',
#   'think',
#   'laughing',
#   'sometimesi',
#   'often',
#   'laughing',
#   'entrepreneur',
#   'like',
#   'everyone',
#   'else',
#   'seems',
#   'lovewhat',
#   'enjoy',
#   'parties',
#   'downtime',
#   'equal',
#   'measure',
#   'intelligence',
#   'really',
#   'turns',
#   'love',
#   'people',
#   'teach',
#   'menew',
#   'things'],
#  ['names',
#   'jake',
#   'creative',
#   'guy',
#   'look',
#   'others',
#   'easy',
#   'going',
#   'practical',
#   'many',
#   'hang',
#   'ups',
#   'iappreciate',
#   'life',
#   'try',
#   'live',
#   'fullest',
#   'sober',
#   'andhave',
#   'past',
#   'years',
#   'love',
#   'music',
#   'play',
#   'guitar',
#   'like',
#   'tons',
#   'different',
#   'bands',
#   'man',
#   'artist',
#   'love',
#   'paint',
#   'draw',
#   'etc',
#   'love',
#   'creativepeople',
#   'got',
#   'say',
#   'big',
#   'internet',
#   'dating',
#   'cant',
#   'reallyget',
#   'earnest',
#   'impression',
#   'anyone',
#   'polished',
#   'paragraphs',
#   'see',
#   'never',
#   'know'],
#  ['born',
#   'wisconsin',
#   'grew',
#   'iowa',
#   'moved',
#   'californiathree',
#   'years',
#   'ago',
#   'combination',
#   'work',
#   'opportunity',
#   'justwanting',
#   'live',
#   'took',
#   'couple',
#   'years',
#   'get',
#   'thepeninsula',
#   'glad',
#   'eventually',
#   'got',
#   'passionate',
#   'aboutpeople',
#   'wide',
#   'variety',
#   'interests',
#   'talents',
#   'also',
#   'continually',
#   'learning',
#   'example',
#   'mlearning',
#   'recently',
#   'result',
#   'spending',
#   'timegrowing',
#   'college',
#   'last',
#   'five',
#   'years',
#   'focusing',
#   'ongrowing',
#   'deep',
#   'relationship',
#   'skills',
#   'good',
#   'ipreviously',
#   'thought',
#   'initializing',
#   'friendships',
#   'relationships',
#   'iguess',
#   'bad',
#   'thing',
#   'since',
#   'first',
#   'impression',
#   'thingonly',
#   'really',
#   'happens',
#   'person',
#   'result',
#   'love',
#   'friends',
#   'got',
#   'lot',
#   'deep',
#   'friendships',
#   'know',
#   'much',
#   'richer',
#   'friendship',
#   'get',
#   'getsdeeper',
#   'passionate',
#   'music',
#   'play',
#   'guitar',
#   'write',
#   'songs',
#   'lessnow',
#   'write',
#   'plays',
#   'want',
#   'learnfrench',
#   'asl',
#   'pretty',
#   'good',
#   'amateur',
#   'ballroom',
#   'dancer',
#   'cando',
#   'almost',
#   'everything',
#   'moderately',
#   'well',
#   'seriously',
#   'joke',
#   'lovebright',
#   'ties',
#   'shoes',
#   'jacket',
#   'jeans',
#   'person',
#   'absolutelylove',
#   'figuring',
#   'people',
#   'tick',
#   'think',
#   'pretty',
#   'cool',
#   'wishmore',
#   'people',
#   'would',
#   'patient',
#   'enough',
#   'take',
#   'time',
#   'seethat',
#   'every',
#   'friend',
#   'ever',
#   'say',
#   'nothing',
#   'like',
#   'anyone',
#   'else',
#   'idon',
#   'come',
#   'like',
#   'anyone',
#   'else',
#   'person',
#   'proudof'],
#  ['moved',
#   'bay',
#   'area',
#   'austin',
#   'originally',
#   'fromlouisiana',
#   'audio',
#   'programming',
#   'video',
#   'games',
#   'juststarted',
#   'game',
#   'studio',
#   'yes',
#   'bit',
#   'nerdyprogrammer',
#   'stamped',
#   'across',
#   'forehead',
#   'idon',
#   'even',
#   'really',
#   'play',
#   'video',
#   'games',
#   'often',
#   'actuallycreate',
#   'play',
#   'music',
#   'way',
#   'often',
#   'spare',
#   'time',
#   'starting',
#   'new',
#   'life',
#   'really',
#   'excited',
#   'ionly',
#   'knew',
#   'one',
#   'person',
#   'area',
#   'moved',
#   'tworried',
#   'always',
#   'make',
#   'friends',
#   'pretty',
#   'quickly',
#   'every',
#   'city',
#   'velived',
#   'made',
#   'least',
#   'life',
#   'long',
#   'friends',
#   'definitelylooking',
#   'thing',
#   'easy',
#   'get',
#   'along',
#   'kind',
#   'person',
#   'always',
#   'try',
#   'toavoid',
#   'complication',
#   'time',
#   'bullshit',
#   'wouldexpect',
#   'anyone',
#   'close',
#   'respect',
#   'much',
#   'things',
#   'outside',
#   'living',
#   'healthy',
#   'fitlifestyle',
#   'really',
#   'looking',
#   'forward',
#   'camping',
#   'backpacking',
#   'biking',
#   'etc',
#   'also',
#   'really',
#   'enjoy',
#   'going',
#   'anice',
#   'meal',
#   'tasty',
#   'cocktails',
#   'beer',
#   'musicnightlife',
#   'thing',
#   'drum',
#   'bass',
#   'time',
#   'time',
#   'vealready',
#   'landed',
#   'gigs',
#   'bay',
#   'area',
#   'much',
#   'involvedin',
#   'dnb',
#   'electronic',
#   'genres',
#   'love',
#   'live',
#   'music',
#   'asmuch',
#   'basically',
#   'life',
#   'working',
#   'hard',
#   'playing',
#   'hard',
#   'made',
#   'lot',
#   'sacrifices',
#   'invested',
#   'much',
#   'effort',
#   'getmyself',
#   'industry',
#   'two',
#   'often',
#   'overlap',
#   'issomething',
#   'fairly',
#   'proud',
#   'learned',
#   'lot',
#   'ofcool',
#   'stuff',
#   'far',
#   'plan',
#   'continue',
#   'prettyexcited',
#   'see',
#   'take'],
#  ['favorite',
#   'things',
#   'riding',
#   'motorcycle',
#   'curvy',
#   'roadscurling',
#   'next',
#   'book',
#   'seriesfinding',
#   'great',
#   'photographsbuilding',
#   'thingsjoking',
#   'around',
#   'friends',
#   'finding',
#   'funny',
#   'momentsthe',
#   'starswindy',
#   'daysliving',
#   'near',
#   'beachlove',
#   'compassionmusiccooking',
#   'dinner',
#   'friendsometimes',
#   'take',
#   'different',
#   'route',
#   'see',
#   'itgoes',
#   'photos',
#   'available',
#   'facebook',
#   'peak',
#   'thoseunguarded',
#   'moments'],
#  ['relocated',
#   'san',
#   'francisco',
#   'half',
#   'year',
#   'ago',
#   'awesomefew',
#   'months',
#   'let',
#   'explore',
#   'diverse',
#   'parts',
#   'city',
#   'finda',
#   'gorgeous',
#   'victorian',
#   'house',
#   'live',
#   'meet',
#   'awesome',
#   'roommateswho',
#   'became',
#   'best',
#   'friends',
#   'find',
#   'first',
#   'american',
#   'emotionalsoul',
#   'mates',
#   'ride',
#   'hot',
#   'european',
#   'wheels',
#   'hilly',
#   'streets',
#   'sanfrancisco',
#   'winding',
#   'road',
#   'stinson',
#   'beach',
#   'swim',
#   'thefreezing',
#   'waters',
#   'bay',
#   'walk',
#   'ocean',
#   'beach',
#   'full',
#   'moon',
#   'onwarm',
#   'starry',
#   'nights',
#   'experience',
#   'great',
#   'outdoors',
#   'hiking',
#   'andcross',
#   'country',
#   'skiing',
#   'fall',
#   'love',
#   'local',
#   'diversity',
#   'andopenness',
#   'abundance',
#   'cuisine',
#   'embracement',
#   'activelifestyle',
#   'awesome',
#   'city',
#   'live',
#   'one',
#   'canloose',
#   'continuous',
#   'chase',
#   'newelties',
#   'adventure',
#   'people',
#   'around',
#   'support',
#   'amazing',
#   'run',
#   'fornew',
#   'experiences',
#   'absorbing',
#   'atmosphere',
#   'pastsix',
#   'months',
#   'finally',
#   'revelling',
#   'clamness',
#   'findinside',
#   'like',
#   'maybe',
#   'many',
#   'bright',
#   'peoplehere',
#   'come',
#   'embrace',
#   'city',
#   'home',
#   'beginning',
#   'tostabilize',
#   'live',
#   'well',
#   'paced',
#   'life',
#   'time',
#   'personal',
#   'andprofessional',
#   'growth',
#   'fun',
#   'close',
#   'friends',
#   'sports',
#   'keep',
#   'thebalance',
#   'body',
#   'mind',
#   'time',
#   'ponder',
#   'andreflect',
#   'way',
#   'life'],
#  ['tend',
#   'think',
#   'way',
#   'comedian',
#   'nearlyeverything',
#   'laugh',
#   'particular',
#   'activity',
#   'adventures',
#   'key',
#   'ingredient',
#   'happiness',
#   'whether',
#   'anew',
#   'restaurant',
#   'hike',
#   'sport',
#   'usually',
#   'forging',
#   'ahead',
#   'towardsomething',
#   'new',
#   'coming'],
#  ['completely',
#   'fake',
#   'summary',
#   'wrote',
#   'feeling',
#   'coy',
#   'like',
#   'nature',
#   'know',
#   'like',
#   'plants',
#   'sticks',
#   'stuff',
#   'like',
#   'ilike',
#   'girl',
#   'special',
#   'things',
#   'like',
#   'might',
#   'wear',
#   'ado',
#   'rag',
#   'maybe',
#   'spray',
#   'paint',
#   'car',
#   'little',
#   'things',
#   'reallycrushin',
#   'girl',
#   'light',
#   'incense',
#   'put',
#   'fancy',
#   'robe',
#   'sing',
#   'kid',
#   'rock',
#   'songs',
#   'cook',
#   'hamburgerhelper',
#   'real',
#   'bit',
#   'clumsy',
#   'expert',
#   'silly',
#   'dancing',
#   'grew',
#   'ina',
#   'ghost',
#   'town',
#   'like',
#   'living',
#   'simply',
#   'enjoy',
#   'subtlety',
#   'creativity',
#   'nostalgia',
#   'quaint',
#   'old',
#   'fashioned',
#   'things',
#   'makemistakes',
#   'always',
#   'try',
#   'right',
#   'thing',
#   'richman',
#   'got',
#   'heart',
#   'gold',
#   'honest',
#   'good',
#   'natured',
#   'bee',
#   'knees'],
#  ['bay',
#   'area',
#   'transplant',
#   'six',
#   'years',
#   'straight',
#   'outta',
#   'tennessee',
#   'play',
#   'sum',
#   'musick',
#   'make',
#   'sum',
#   'things',
#   'goes',
#   'shows',
#   'preferspersonal',
#   'interaction',
#   'social',
#   'interaction',
#   'like',
#   'outalot',
#   'everybody',
#   'shuld',
#   'stop',
#   'smell',
#   'roses',
#   'timeand',
#   'lets',
#   'see',
#   'wuld',
#   'happen',
#   'swear',
#   'really',
#   'abad',
#   'speller',
#   'unique',
#   'method',
#   'typing',
#   'acar',
#   'really',
#   'good',
#   'driver',
#   'think',
#   'generally',
#   'prettypleasant',
#   'person',
#   'hang',
#   'dunno',
#   'tell',
#   'like',
#   'toride',
#   'bike',
#   'really',
#   'slowly',
#   'helmet',
#   'people',
#   'think',
#   'ilook',
#   'like',
#   'weezer',
#   'guess',
#   'really',
#   'see',
#   'theresemblance'],
#  ['hey',
#   'hope',
#   'well',
#   'great',
#   'summer',
#   'vebeen',
#   'denver',
#   'back',
#   'till',
#   '12th',
#   'talk',
#   'youthen',
#   'currently',
#   'work',
#   'graphic',
#   'designer',
#   'focused',
#   'marketing',
#   'andadvertising',
#   'graduated',
#   'university',
#   'colorado',
#   'boulderclass',
#   'humble',
#   'energetic',
#   'willing',
#   'optimistic',
#   'honestand',
#   'lot',
#   'gratitude',
#   'live',
#   'today',
#   'moment',
#   'andthat',
#   'important',
#   'believe',
#   'succcess',
#   'without',
#   'stepping',
#   'ontoes',
#   'positive',
#   'strive',
#   'best',
#   'positivityand',
#   'humor',
#   'key',
#   'laughter',
#   'specialty',
#   'looking',
#   'meet',
#   'new',
#   'friends',
#   'possibly',
#   'something',
#   'ihave',
#   'expectations',
#   'keep',
#   'eyes',
#   'open',
#   'special',
#   'girlto',
#   'see',
#   'goes',
#   'consider',
#   'gentleman',
#   'child',
#   'heart',
#   'alot',
#   'energy',
#   'mean',
#   'immature',
#   'way',
#   'lot',
#   'funand',
#   'anything',
#   'raised',
#   'good',
#   'family',
#   'beenlucky',
#   'enough',
#   'travel',
#   'around',
#   'world',
#   'plan',
#   'keeping',
#   'thatup',
#   'enjoy',
#   'japanese',
#   'culture',
#   'oahu',
#   'beautiful',
#   'oceans',
#   'north',
#   'shore',
#   'waimea',
#   'bay',
#   'pipeline',
#   'kailua',
#   'makapu',
#   'sandy',
#   'music',
#   'mydog',
#   'side',
#   'staying',
#   'watching',
#   'movies',
#   'dating',
#   'sweethearts',
#   'ipad',
#   'iphone',
#   'dining',
#   'traveling',
#   'snowboarding',
#   'fly',
#   'fishing',
#   'camping',
#   'watching',
#   'pro',
#   'sports',
#   'aimlessly',
#   'running',
#   'around',
#   'city',
#   'watching',
#   'movies',
#   'bed',
#   'taking',
#   'driving',
#   'range',
#   'surfingwith',
#   'older',
#   'brother',
#   'cycling',
#   'going',
#   'shows',
#   'city',
#   'andgoing',
#   'friends'],
#  ['full',
#   'time',
#   'student',
#   'full',
#   'time',
#   'square',
#   'change',
#   'year',
#   'year',
#   'used',
#   'love',
#   'computer',
#   'games',
#   'drinking',
#   'finding',
#   'hatethem',
#   'time',
#   'passes',
#   'get',
#   'wrong',
#   'still',
#   'enjoy',
#   'nightout',
#   'every',
#   'month',
#   'lazy',
#   'saturday',
#   'computer',
#   'andagain',
#   'obsession',
#   'moment',
#   'include',
#   'long',
#   'drives',
#   'nightafter',
#   'work',
#   'hitting',
#   'gym',
#   'weekends',
#   'like',
#   'sit',
#   'andhome',
#   'prepare',
#   'week',
#   'ahead'],
#  ['lost', 'needle', 'haystack', 'found', 'prettymuch', 'sums'],
#  ['love',
#   'life',
#   'okcupid',
#   'telling',
#   'three',
#   'words',
#   'enough',
#   'okthen',
#   'moved',
#   'bay',
#   'area',
#   'february',
#   'know',
#   'anyone',
#   'chance',
#   'pretend',
#   'coolest',
#   'kid',
#   'townand',
#   'know',
#   'better',
#   'believe',
#   'still',
#   'enough',
#   'fine',
#   'detailed',
#   'description',
#   'born',
#   'lead',
#   'armies',
#   'darkness',
#   'ruinous',
#   'victory',
#   'gifted',
#   'witha',
#   'vast',
#   'range',
#   'abilities',
#   'achieving',
#   'destiny',
#   'cursed',
#   'theforces',
#   'good',
#   'crippled',
#   'ethics',
#   'honesty',
#   'compassion',
#   'usual',
#   'story',
#   'good',
#   'triumphs',
#   'evil',
#   'foiled',
#   'blah',
#   'blahblah',
#   'read',
#   'write',
#   'name',
#   'job',
#   'home',
#   'carand',
#   'teeth',
#   'use',
#   'oscilloscope',
#   'showermyself',
#   'also',
#   'know',
#   'people',
#   'recently',
#   'published',
#   'loathsome',
#   'people',
#   'usa',
#   'list',
#   'single',
#   'one',
#   'ofthem',
#   'mom',
#   'delighted',
#   'hear',
#   'though',
#   'youmay',
#   'feel',
#   'little',
#   'bit',
#   'insulted',
#   'poorly',
#   'hidden',
#   'relief'],
#  ['grew',
#   'new',
#   'york',
#   'san',
#   'diego',
#   'half',
#   'half',
#   'root',
#   'theknicks',
#   'mets',
#   'jets',
#   'around',
#   'cheat',
#   'thepadres',
#   'chargers',
#   'prefer',
#   'happy',
#   'hour',
#   'last',
#   'call',
#   'use',
#   'sound',
#   'effects',
#   'story',
#   'telli'],
#  ['really',
#   'like',
#   'summarizing',
#   'right',
#   'seemslike',
#   'every',
#   'time',
#   'try',
#   'come',
#   'pile',
#   'ofcontradictions',
#   'shy',
#   'extroverti',
#   'grounded',
#   'dreameri',
#   'lazy',
#   'adventureri',
#   'open',
#   'minded',
#   'sometimes',
#   'stubborni',
#   'city',
#   'person',
#   'mountain',
#   'mani',
#   'competitive',
#   'try',
#   'avoid',
#   'competitioni',
#   'social',
#   'bit',
#   'misanthropici',
#   'generally',
#   'meticulous',
#   'often',
#   'sort',
#   'carelessi',
#   'strong',
#   'sense',
#   'self',
#   'social',
#   'chameleoni',
#   'complete',
#   'confidence',
#   'succeed',
#   'whatever',
#   'yet',
#   'often',
#   'terrified',
#   'failure',
#   'letting',
#   'others',
#   'lot',
#   'best',
#   'friends',
#   'like',
#   'first',
#   'metme',
#   'took',
#   'time',
#   'get',
#   'know',
#   'figured',
#   'thati',
#   'actually',
#   'caring',
#   'entertaining',
#   'giving',
#   'honest',
#   'loyal',
#   'patient',
#   'playful',
#   'open',
#   'stimulating',
#   'companion',
#   'course',
#   'otherslove',
#   'first',
#   'sight',
#   'never',
#   'stop',
#   'maybe',
#   'seefor',
#   'clever',
#   'creative',
#   'complicated'],
#  ['free', 'culture', 'nerd', 'travel', 'talk', 'teach'],
#  ['originally',
#   'france',
#   'lived',
#   'different',
#   'countries',
#   'moved',
#   'here3',
#   'years',
#   'ago',
#   'totally',
#   'fell',
#   'love',
#   'bay',
#   'area',
#   'justlooking',
#   'meet',
#   'new',
#   'people',
#   'hangout',
#   'explore',
#   'area',
#   'ilove',
#   'travel',
#   'fact',
#   'got',
#   'back',
#   'central',
#   'america',
#   'wherei',
#   'spent',
#   'month',
#   'short',
#   'also',
#   'love',
#   'outdoors',
#   'going',
#   'adventures',
#   'rock',
#   'climbing',
#   'snowboarding',
#   'hiking',
#   'kayaking',
#   'name',
#   'also',
#   'started',
#   'keep',
#   'bees',
#   'backyard',
#   'really',
#   'afascinating',
#   'hobby',
#   'get',
#   'delicious',
#   'local',
#   'honey'],
#  ['grew',
#   'iowa',
#   'gets',
#   'bad',
#   'rap',
#   'let',
#   'first',
#   'totell',
#   'youiowa',
#   'way',
#   'cooler',
#   'think',
#   'iowa',
#   'iwent',
#   'school',
#   'pittsburgh',
#   'spending',
#   'summer',
#   'sanfrancisco',
#   'living',
#   'soma',
#   'know',
#   'guy',
#   'always',
#   'researching',
#   'analyzing',
#   'know',
#   'friend',
#   'working',
#   'project',
#   'send',
#   'relevantideas',
#   'articles',
#   'come',
#   'across',
#   'however',
#   'intellectual',
#   'prowessdoesn',
#   'permeate',
#   'aspects',
#   'life',
#   'friends',
#   'make',
#   'fun',
#   'ofme',
#   'absent',
#   'minded',
#   'professor',
#   'type',
#   'give',
#   'hard',
#   'problemand',
#   'excel',
#   'moving',
#   'apartment',
#   'might',
#   'well',
#   'berocket',
#   'science',
#   'eek',
#   'always',
#   'room',
#   'improvement',
#   'love',
#   'sound',
#   'plane',
#   'tires',
#   'touching',
#   'country',
#   'venever',
#   'visited',
#   'japan',
#   'next',
#   'list',
#   'though',
#   'visit',
#   'germanyor',
#   'london',
#   'heartbeat',
#   'intuitive',
#   'side',
#   'life',
#   'recently',
#   'beenenthusiastically',
#   'exploring',
#   'buddhism',
#   'meditation',
#   'payingattention',
#   'spaces',
#   'things',
#   'learn',
#   'theless',
#   'know',
#   'refreshing',
#   'awash',
#   'mystery',
#   'theuniverse',
#   'style',
#   'important',
#   'expression',
#   'clothingbut',
#   'draw',
#   'line',
#   'pajamas',
#   'outerwear',
#   'get',
#   'recomfortable',
#   'know',
#   'saying'],
#  ['straight',
#   'point',
#   'sugar',
#   'coat',
#   'mean',
#   'well',
#   'sarcastic',
#   'anda',
#   'clown',
#   'good',
#   'friend',
#   'talk',
#   'clumsy',
#   'yeah',
#   'fall',
#   'overmyself',
#   'kid',
#   'heart',
#   'still',
#   'dreamin',
#   'big',
#   'dreams',
#   'bad',
#   'withnames',
#   'known',
#   'get',
#   'spot',
#   'white',
#   'shirt',
#   'inevitable',
#   'ilike',
#   'iron',
#   'clothes',
#   'relaxing',
#   'running',
#   'gets',
#   'theendorphins',
#   'going',
#   'convinced',
#   'matching',
#   'online',
#   'thing',
#   'yet',
#   'still',
#   'anything',
#   'spossible',
#   'still',
#   'reading',
#   'maybe',
#   'still',
#   'interested',
#   'curious',
#   'hey',
#   'looking',
#   'perfect',
#   'exist',
#   'thewhole',
#   'maybe',
#   'different',
#   'maybe',
#   'lots',
#   'imperfections',
#   'butmaybe',
#   'perfect',
#   'know'],
#  ['really',
#   'like',
#   'meeting',
#   'new',
#   'people',
#   'small',
#   'world',
#   'networks',
#   'fascinateme',
#   'beer',
#   'important',
#   'without',
#   'beer',
#   'would',
#   'nocivilization',
#   'somehow',
#   'sing',
#   'spanish',
#   'speak',
#   'suppose',
#   'musicis',
#   'universal',
#   'language',
#   'coffee',
#   'enthusiast',
#   'one',
#   'singing',
#   'riding',
#   'bike',
#   'around',
#   'themission'],
#  ['way',
#   'boring',
#   'reveal',
#   'plaintext',
#   'guess',
#   'interesting',
#   'discover',
#   'eachother',
#   'person',
#   'plus',
#   'wary',
#   'online',
#   'profiles'],
#  ['adventurer',
#   'first',
#   'take',
#   'calculatedrisks',
#   'whenever',
#   'seems',
#   'fun',
#   'always',
#   'take',
#   'care',
#   'aroundme',
#   'writer',
#   'astory',
#   'teller',
#   'photographer',
#   'things',
#   'arebasically',
#   'thing',
#   'love',
#   'playing',
#   'lights',
#   'sound',
#   'really',
#   'machine',
#   'locomotion',
#   'pretty',
#   'blinky',
#   'thingson',
#   'love',
#   'driving',
#   'racing',
#   'flying',
#   'sailing',
#   'sky',
#   'diving',
#   'adrenaline',
#   'issacred',
#   'said',
#   'appreciate',
#   'night',
#   'home',
#   'goodbook',
#   'bottle',
#   'wine',
#   'company',
#   'movie',
#   'andconversation',
#   'time',
#   'though',
#   'like',
#   'hear',
#   'themovie',
#   'focus',
#   'later'],
#  ['extroverted',
#   'charming',
#   'yet',
#   'enjoy',
#   'living',
#   'alone',
#   'mysanctuary',
#   'apartment',
#   'strong',
#   'dominant',
#   'personalitythat',
#   'tempered',
#   'deep',
#   'stable',
#   'emotions',
#   'comfortable',
#   'withmyself',
#   'flaws',
#   'trying',
#   'work',
#   'selfbetterment',
#   'looking',
#   'unique',
#   'woman',
#   'modest',
#   'herbeauty',
#   'values',
#   'healthy',
#   'active',
#   'lifestyle',
#   'independentbut',
#   'willing',
#   'open',
#   'little',
#   'dependence'],
#  ['raised',
#   'sailor',
#   'taxidermist',
#   'pacific',
#   'norhtwest',
#   'imno',
#   'stranger',
#   'cursing',
#   'whiskey',
#   'swilling',
#   'plainstrange',
#   'ahead',
#   'try',
#   'weirdest',
#   'professional',
#   'student',
#   'life',
#   'pretty',
#   'good',
#   'details',
#   'boring',
#   'get',
#   'fancy',
#   'degree',
#   'one',
#   'ofthese',
#   'days',
#   'importantly',
#   'cat',
#   'allergy',
#   'sorry',
#   'cat',
#   'ladies',
#   'makeme',
#   'sneeze'],
#  ['originally',
#   'southern',
#   'california',
#   'moved',
#   'san',
#   'fransico',
#   'topursue',
#   'degree',
#   'film',
#   'love',
#   'movies',
#   'working',
#   'film',
#   'relatedprojects',
#   'like',
#   'exercising',
#   'staying',
#   'active',
#   'looking',
#   'someoneto',
#   'hang'],
#  ['moved',
#   'months',
#   'ago',
#   'far',
#   'really',
#   'liking',
#   'buti',
#   'looking',
#   'grow',
#   'circle',
#   'friends',
#   'hitting',
#   'acute',
#   'girl',
#   'along',
#   'way',
#   'even',
#   'better',
#   'latest',
#   'interest',
#   'rock',
#   'climbing',
#   'going',
#   'week',
#   'toplanet',
#   'granite',
#   'blast',
#   'perhaps',
#   'good',
#   'way',
#   'meet',
#   'ifyou',
#   'als',
#   'climb',
#   'belay',
#   'partners',
#   'originally',
#   'chicago',
#   'area',
#   'still',
#   'verysmall',
#   'family',
#   'lives',
#   'last',
#   'years',
#   'enjoying',
#   'beaches',
#   'mountains',
#   'deserts',
#   'san',
#   'diego',
#   'adventurer',
#   'heart',
#   'always',
#   'seeking',
#   'something',
#   'theordinary',
#   'challenge',
#   'spark',
#   'imagination',
#   'simplysurprise',
#   'least',
#   'expecting',
#   'ideal',
#   'girl',
#   'would',
#   'thesame',
#   'traveled',
#   'many',
#   'places',
#   'world',
#   'still',
#   'tonleft',
#   'see',
#   'major',
#   'goal',
#   'find',
#   'girl',
#   'sharesthis',
#   'travel',
#   'bug',
#   'point',
#   'next',
#   'years',
#   'dlove',
#   'quit',
#   'job',
#   'travel',
#   '1yr',
#   'girl',
#   'love',
#   'thenreturn',
#   'normal',
#   'life',
#   'career',
#   'lives',
#   'enriched'],
#  ['like',
#   'everyone',
#   'else',
#   'site',
#   'feel',
#   'awkward',
#   'trying',
#   'summyself',
#   'box',
#   'sake',
#   'strangers',
#   'internet',
#   'nowthat',
#   'got',
#   'wayi',
#   'born',
#   'calgary',
#   'spent',
#   'childhood',
#   'around',
#   'area',
#   'came',
#   'sunny',
#   'california',
#   'school',
#   'funny',
#   'loyal',
#   'patient',
#   'cynical',
#   'laid',
#   'back',
#   'dreamer',
#   'something',
#   'hopelessromantic',
#   'big',
#   'believer',
#   'finding',
#   'humor',
#   'everyday',
#   'lifeand',
#   'compulsively',
#   'crack',
#   'wise',
#   'ridiculous',
#   'things',
#   'see',
#   'inadvertisements',
#   'politics',
#   'restaurant',
#   'menus',
#   'etc',
#   'alsosquirrels',
#   'squirrels',
#   'get',
#   'funny',
#   'shit',
#   'love',
#   'read',
#   'andcan',
#   'easily',
#   'spend',
#   'hours',
#   'good',
#   'bookstore',
#   'huge',
#   'cinephileand',
#   'right',
#   'mood',
#   'enjoy',
#   'bad',
#   'movie',
#   'every',
#   'bit',
#   'much',
#   'agood',
#   'one',
#   'see',
#   'aforementioned',
#   'enjoyment',
#   'ridiculous',
#   'afan',
#   'hugs',
#   'backrubs',
#   'giving',
#   'getting',
#   'strongly',
#   'supportwomen',
#   'rights',
#   'gay',
#   'rights',
#   'forms',
#   'socialequality',
#   'might',
#   'get',
#   'along',
#   'well',
#   'justsayin',
#   'love',
#   'music',
#   'also',
#   'appreciate',
#   'good',
#   'stretch',
#   'ofsilence',
#   'every',
#   'love',
#   'collecting',
#   'information',
#   'howthings',
#   'work',
#   'happily',
#   'geek',
#   'obscure',
#   'facet',
#   'ofbiology',
#   'physics',
#   'psychology',
#   'history',
#   'anthropology',
#   'enjoy',
#   'theoutdoors',
#   'even',
#   'though',
#   'get',
#   'often',
#   'like',
#   'especially',
#   'foresty',
#   'areas',
#   'something',
#   'comforting',
#   'trees',
#   'believe',
#   'astrology',
#   'means',
#   'explanation',
#   'forwhy',
#   'almost',
#   'everything',
#   'read',
#   'scorpios',
#   'matches',
#   'dead'],
#  ['mmmmmm', 'idk', 'say', 'ask'],
#  ['still',
#   'new',
#   'moved',
#   'chicago',
#   'last',
#   'august',
#   'wasborn',
#   'philippines',
#   'first',
#   'moved',
#   'almost3',
#   'lead',
#   'pretty',
#   'remarkable',
#   'life',
#   'earned',
#   'lot',
#   'awesomeopportunities',
#   'taken',
#   'advantage',
#   'moving',
#   'around',
#   'thecountry',
#   'since',
#   'family',
#   'moved',
#   'helped',
#   'learn',
#   'seek',
#   'outopportunities',
#   'taught',
#   'able',
#   'put',
#   'outthere',
#   'like',
#   'park',
#   'read',
#   'love',
#   'travel',
#   'anoutdoors',
#   'person',
#   'like',
#   'bouldering',
#   'water',
#   'thefrigid',
#   'ocean',
#   'though',
#   'snowboarding',
#   'soccer',
#   'hiking',
#   'bike',
#   'riding',
#   'andjust',
#   'touring',
#   'city'],
#  ['names',
#   'josh',
#   'create',
#   'art',
#   'living',
#   'work',
#   'aconceptual',
#   'artist',
#   'north',
#   'beach',
#   'studio',
#   'spare',
#   'time',
#   'liketo',
#   'play',
#   'music',
#   'adventure',
#   'around',
#   'city',
#   'check',
#   'music',
#   'justhang',
#   'home',
#   'prefer',
#   'meeting',
#   'people',
#   'real',
#   'life',
#   'notopposed',
#   'meeting',
#   'new',
#   'friends',
#   'internets',
#   'hit',
#   'like',
#   'know'],
#  ['new',
#   'boston',
#   'thought',
#   'might',
#   'good',
#   'way',
#   'tomeet',
#   'new',
#   'people',
#   'instead',
#   'writing',
#   'think',
#   'would',
#   'better',
#   'toldyou',
#   'looking',
#   'always',
#   'meet',
#   'new',
#   'friends',
#   'know',
#   'want',
#   'agirl',
#   'want',
#   'waste',
#   'time',
#   'enjoy',
#   'ordering',
#   'something',
#   'different',
#   'everytime',
#   'arestaurant',
#   'speaking',
#   'restaurants',
#   'offering',
#   'split',
#   'thecheck',
#   'first',
#   'date',
#   'tells',
#   'lot',
#   'person',
#   'thansomeone',
#   'assumes',
#   'taken',
#   'care',
#   'even',
#   'though',
#   'never',
#   'letyou',
#   'tall',
#   'like',
#   'tall',
#   'girls',
#   'sexy',
#   'sweetzone',
#   'ski',
#   'snowboard',
#   'know',
#   'state',
#   'jackson',
#   'hole',
#   'inyou',
#   'pretty',
#   'much',
#   'beat',
#   'everyone',
#   'date',
#   'non',
#   'skier',
#   'texpect',
#   'hang',
#   'powder',
#   'day',
#   'adventures',
#   'fun',
#   'lazy',
#   'like',
#   'new',
#   'things',
#   'time',
#   'mother',
#   'taught',
#   'cook',
#   'great',
#   'atsome',
#   'point',
#   'make',
#   'cook',
#   'know',
#   'itsnot',
#   'try',
#   'pepper',
#   'best',
#   'soda',
#   'hate',
#   'tappreciate',
#   'owning',
#   'gym',
#   'membership',
#   'good',
#   'thing',
#   'hiding',
#   'secret',
#   'talents',
#   'amazing',
#   'things',
#   'want',
#   'tosee',
#   'people',
#   'use',
#   'number',
#   'instead',
#   'stupid',
#   'importantly',
#   'dateable',
#   'sleep',
#   'withsomeone',
#   'first',
#   'night'],
#  ['like',
#   'horses',
#   'horses',
#   'understanding',
#   'ladieslove',
#   'horses',
#   'always',
#   'horse',
#   'ing',
#   'around',
#   'please',
#   'sing',
#   'hey',
#   'soul',
#   'sister',
#   'like',
#   'hay',
#   'getit',
#   'sing',
#   'hey',
#   'soul',
#   'sister',
#   'pulling',
#   'train',
#   'ido',
#   'want',
#   'train',
#   'pulled',
#   'witty',
#   'may',
#   'travel',
#   'list',
#   'places',
#   'vevisi',
#   'last',
#   'years',
#   'big',
#   'sur',
#   'death',
#   'valley',
#   'guilin',
#   'guyana',
#   'hollister',
#   'hong',
#   'kong',
#   'horseheaven',
#   'hills',
#   'iceland',
#   'king',
#   'canyon',
#   'las',
#   'vegas',
#   'lassen',
#   'macau',
#   'mexico',
#   'city',
#   'mono',
#   'lake',
#   'oaxaca',
#   'nova',
#   'scotia',
#   'red',
#   'mountain',
#   'sequoia',
#   'trinidad',
#   'yosemite',
#   'mom',
#   'houseam',
#   'dead',
#   'pan',
#   'questing',
#   'mark',
#   'indecisive',
#   'indincisive'],
#  ['mein',
#   'nutshell',
#   'easy',
#   'going',
#   'earth',
#   'kind',
#   'guy',
#   'whoappreciates',
#   'life',
#   'great',
#   'things',
#   'offer',
#   'afterall',
#   'purpose',
#   'life',
#   'make',
#   'lasting',
#   'memories',
#   'workhard',
#   'play',
#   'hard',
#   'soft',
#   'spot',
#   'outdoors',
#   'avidhiker',
#   'camper',
#   'beach',
#   'relaxer',
#   'always',
#   'open',
#   'trying',
#   'newthings',
#   'friends',
#   'soon',
#   'friends'],
#  ['friend',
#   'suggested',
#   'try',
#   'online',
#   'thing',
#   'see',
#   'whatit',
#   'like',
#   'let',
#   'know',
#   'feel',
#   'totally',
#   'weird',
#   'andit',
#   'even',
#   'feels',
#   'bit',
#   'creepy',
#   'hell',
#   'right',
#   'goes',
#   'grew',
#   'humble',
#   'country',
#   'boy',
#   'rolling',
#   'fields',
#   'centralmassachusetts',
#   'riding',
#   'bike',
#   'playing',
#   'woods',
#   'went',
#   'umass',
#   'amherst',
#   'moved',
#   'boston',
#   'waslandscape',
#   'architect',
#   'park',
#   'planner',
#   'national',
#   'parkservice',
#   'left',
#   'dream',
#   'job',
#   'become',
#   'full',
#   'time',
#   'musician',
#   'drums',
#   'andbandleader',
#   'years',
#   'left',
#   'dream',
#   'job',
#   'move',
#   'got',
#   'teaching',
#   'credential',
#   'atuniversity',
#   'san',
#   'francisco',
#   'wrapping',
#   'mastersthere',
#   'currently',
#   'teaching',
#   'high',
#   'school',
#   'science',
#   'public',
#   'charter',
#   'herein',
#   'san',
#   'francisco',
#   'loving',
#   'another',
#   'dream',
#   'job',
#   'within',
#   'years',
#   'innumerable',
#   'adventures',
#   'countless',
#   'friends',
#   'lost',
#   'loves',
#   'hit',
#   'misses',
#   'many',
#   'proverbial',
#   'roller',
#   'coasterrides',
#   'tell',
#   'ever',
#   'meet'],
#  ['temporary',
#   'hiatus',
#   'trying',
#   'define',
#   'particularly',
#   'concise',
#   'blurbs',
#   'however',
#   'finding',
#   'thisreluctance',
#   'summarize',
#   'might',
#   'adversely',
#   'affecting',
#   'mysocio',
#   'economic',
#   'success',
#   'levels',
#   'found',
#   'blurb',
#   'wordy',
#   'confusing',
#   'wholly',
#   'devoid',
#   'humor',
#   'irony',
#   'likely',
#   'find',
#   'meannoying'],
#  ['sean',
#   'sites',
#   'always',
#   'wired',
#   'experience',
#   'obviously',
#   'free',
#   'well',
#   'meetpeople',
#   'feel',
#   'free',
#   'shoot',
#   'message',
#   'want',
#   'thats',
#   'whywere',
#   'right',
#   'still',
#   'going',
#   'school',
#   'workingas',
#   'medic',
#   'right',
#   'lots',
#   'crazy',
#   'story',
#   'wana',
#   'hearthem',
#   'eather',
#   'going',
#   'straight',
#   'med',
#   'school',
#   'intobusiness',
#   'take',
#   'fathers',
#   'business',
#   'well',
#   'see',
#   'happens',
#   'hope',
#   'hear',
#   'soon'],
#  ['business',
#   'owner',
#   'backend',
#   'frontend',
#   'developer',
#   'frequent',
#   'hiker',
#   'apodcast',
#   'listener',
#   'trying',
#   'banjo',
#   'player',
#   'former',
#   'bass',
#   'player',
#   'former',
#   'inorganic',
#   'chemist',
#   'former',
#   'theoretical',
#   'magneticresonator',
#   'realized',
#   'staring',
#   'lava',
#   'feet',
#   'away',
#   'havingit',
#   'toss',
#   'bits',
#   'molten',
#   'rock',
#   'probably',
#   'single',
#   'greatestthing',
#   'world',
#   'gonna',
#   'hear',
#   'lady',
#   'help',
#   'raised',
#   'southern',
#   'style',
#   'southern',
#   'cali',
#   'accentonly',
#   'comes',
#   'provoked',
#   'similar',
#   'company',
#   'beverageinduced',
#   'aikidoist',
#   'hip',
#   'hop',
#   'banjo',
#   'lover',
#   'waiting',
#   'thatgenre',
#   'created',
#   'former',
#   'chemist',
#   'turned',
#   'business',
#   'owner',
#   'frequent',
#   'traveler',
#   'itgets',
#   'boring',
#   'sitting',
#   'one',
#   'spot',
#   'long',
#   'really',
#   'liketo',
#   'new',
#   'spot',
#   'sit',
#   'drive',
#   'fast',
#   'expect',
#   'people',
#   'better',
#   'drivers',
#   'theyare',
#   'shall',
#   'let',
#   'known',
#   'really',
#   'open',
#   'ness',
#   'crap',
#   'may',
#   'ask',
#   'answer',
#   'oakland',
#   'bag',
#   'tried',
#   'like',
#   'even',
#   'like',
#   'dealing',
#   'withmore',
#   'one',
#   'conversation',
#   'time',
#   'could',
#   'atime',
#   'thing',
#   'intj',
#   'unite',
#   'right',
#   'heard',
#   'matters',
#   'anything',
#   'according',
#   'two',
#   'signs',
#   'aries',
#   'dragon',
#   'psych',
#   'profile',
#   'intj',
#   'anintroverted',
#   'good',
#   'money',
#   'loyal',
#   'slightly',
#   'competitive',
#   'overgeneralizing',
#   'asshole',
#   'uncanny',
#   'ability',
#   'focus',
#   'mostlytrue',
#   'basically',
#   'lookin',
#   'partner',
#   'crime',
#   'really',
#   'likegames',
#   'tend',
#   'lose',
#   'lot',
#   'prefer',
#   'play',
#   'themanymore',
#   'like',
#   'side',
#   'iget',
#   'sheesh',
#   'questions',
#   'madquestion',
#   'website',
#   'right',
#   'gummy',
#   'worms',
#   'gummy',
#   'bears',
#   'red',
#   'blue',
#   'green',
#   'say',
#   'yellow',
#   'orange',
#   'brown',
#   'disqualified',
#   'bla',
#   'fleck',
#   'tony',
#   'trischka',
#   'brooklyn',
#   'trees',
#   'snow',
#   'sand'],
#  ['almost', 'decided', 'want', 'igrow'],
#  ['graduated',
#   'berkeley',
#   'degree',
#   'eecs',
#   'electricalengineering',
#   'computer',
#   'science',
#   'enjoy',
#   'things',
#   'withcomputer',
#   'cars',
#   'two',
#   'main',
#   'hobbies',
#   'immigrated',
#   'settled',
#   'losangeles',
#   'amusing',
#   'funny',
#   'geeky'],
#  ['single',
#   'girls',
#   'come',
#   'get',
#   'hahahai',
#   'tall',
#   'white',
#   'guy',
#   'looking',
#   'younger',
#   'woman',
#   'ask',
#   'meanything',
#   'would',
#   'like',
#   'know'],
#  ['ill',
#   'matic',
#   'drastically',
#   'fantastic',
#   'orgasmic',
#   'incomparable',
#   'plastic',
#   'seen',
#   'drastic',
#   'spastic',
#   'yet',
#   'prophetic',
#   'facts',
#   'areprophylactic'],
#  ['sorry',
#   'lack',
#   'detailed',
#   'pictures',
#   'lot',
#   'friends',
#   'andcolleagues',
#   'visit',
#   'site',
#   'pretty',
#   'sure',
#   'wouldrecognize'],
#  ['upon',
#   'viewing',
#   'big',
#   'empty',
#   'box',
#   'big',
#   'case',
#   'stage',
#   'fright',
#   'kinda',
#   'like',
#   'pushed',
#   'stage',
#   'front',
#   'mike',
#   'andsomeone',
#   'turned',
#   'big',
#   'spotlight',
#   'tap',
#   'tap',
#   'thing',
#   'yep',
#   'start',
#   'could',
#   'add',
#   'fourth',
#   'adjective',
#   'would',
#   'optimistic',
#   'theglass',
#   'always',
#   'half',
#   'full',
#   'enough',
#   'share',
#   'far',
#   'pollyannic',
#   'rational',
#   'funny',
#   'shy'],
#  ['part',
#   'geek',
#   'part',
#   'silly',
#   'part',
#   'ridiculous',
#   'guy',
#   'always',
#   'open',
#   'tomeeting',
#   'new',
#   'people',
#   'seeing',
#   'click',
#   'geek',
#   'always',
#   'game',
#   'intellectually',
#   'stimulatingconversation',
#   'consider',
#   'sapiosexual',
#   'thesame',
#   'certainly',
#   'get',
#   'along',
#   'definitely',
#   'somewhat',
#   'silly',
#   'guilty',
#   'personmaking',
#   'ridiculous',
#   'expressions',
#   'pictures',
#   'desperatelytry',
#   'scrub',
#   'facebook',
#   'ridiculous',
#   'part',
#   'like',
#   'try',
#   'completely',
#   'new',
#   'thingsnot',
#   'comfort',
#   'zone',
#   'bonus',
#   'points',
#   'triggers',
#   'adrenalinejunkie',
#   'would',
#   'love',
#   'try',
#   'something',
#   'new',
#   'somethingin',
#   'mind',
#   'furthermore',
#   'engineer',
#   'profession',
#   'spent',
#   'childhood',
#   'tinkering',
#   'andbreaking',
#   'things',
#   'somehow',
#   'turned',
#   'career',
#   'bay',
#   'area',
#   'product',
#   'grew',
#   'san',
#   'jose',
#   'went',
#   'school',
#   'inberkeley',
#   'bears',
#   'san',
#   'francisco',
#   'somewhere',
#   'entp',
#   'intp',
#   'hardcore',
#   'car',
#   'person',
#   'average',
#   'guy',
#   'drivesaggressively',
#   'someone',
#   'spends',
#   'many',
#   'weekends',
#   'racetrack',
#   'secretly',
#   'dream',
#   'one',
#   'day',
#   'professionally',
#   'hobbies',
#   'picked',
#   'photography',
#   'cycling',
#   'foodie',
#   'ing',
#   'fashion',
#   'becoming',
#   'quite',
#   'yuppie',
#   'decently',
#   'athletic',
#   'though',
#   'slightly',
#   'slower',
#   'used',
#   'atswimming',
#   'argh',
#   'optimistic',
#   'competitive',
#   'stubborn'],
#  ['although',
#   'live',
#   'yet',
#   'moving',
#   'since',
#   'know',
#   'two',
#   'people',
#   'city',
#   'would',
#   'cool',
#   'tomeet',
#   'new',
#   'people',
#   'good',
#   'describing',
#   'like',
#   'anything',
#   'fun',
#   'going',
#   'outto',
#   'shows',
#   'bars',
#   'restaurants',
#   'traveling',
#   'far',
#   'away',
#   'countries',
#   'gettinginto',
#   'squirt',
#   'gun',
#   'fights',
#   'strangers',
#   'usual',
#   'know',
#   'beernerd',
#   'computer',
#   'geek',
#   'describe'],
#  ['hmmmm',
#   'impossible',
#   'describe',
#   'least',
#   'wiithoutsounding',
#   'like',
#   'applying',
#   'job',
#   'mathy',
#   'nerdy',
#   'guy',
#   'enjoys',
#   'figuring',
#   'things',
#   'enjoyinghimself',
#   'also',
#   'making',
#   'innuendos',
#   'also',
#   'enjoys',
#   'humor',
#   'espcially',
#   'internet',
#   'humor',
#   'theorizing',
#   'abouttime',
#   'travel',
#   'high',
#   'school',
#   'came',
#   'proof',
#   'icould',
#   'define',
#   'whatever',
#   'wanted',
#   'true',
#   'based',
#   'around',
#   'time',
#   'travel',
#   'somehow',
#   'friends',
#   'quite',
#   'convinced',
#   'things',
#   'like',
#   'thinking',
#   'things',
#   'likefiguring',
#   'universe',
#   'way',
#   'society',
#   'howit',
#   'politics',
#   'sucks',
#   'much',
#   'plural',
#   'lookingwords',
#   'actually',
#   'singular',
#   'also',
#   'figuring',
#   'use',
#   'thevarious',
#   'contraptions',
#   'gym',
#   'started',
#   'using',
#   'thati',
#   'actually',
#   'time',
#   'energy',
#   'college',
#   'really',
#   'intense',
#   'awesome',
#   'intense'],
#  ['charmingly',
#   'eccentric',
#   'borderline',
#   'pretentious',
#   'infectiouslyeasygoing',
#   'dude',
#   'thoroughly',
#   'berkelified',
#   'since',
#   'movinghere',
#   'years',
#   'ago',
#   'eat',
#   'vegetables',
#   'think',
#   'like',
#   'tolive',
#   'antarcticasomeday',
#   'bit',
#   'lucky',
#   'come',
#   'probably',
#   'lab',
#   'assistant',
#   'pretend',
#   'toappreciate',
#   'art',
#   'music',
#   'name',
#   'means',
#   'honors',
#   'god',
#   'anatheist',
#   'like',
#   'yes',
#   'know',
#   'sentences',
#   'choppy',
#   'butit',
#   'fun',
#   'way'],
#  ['good',
#   'guy',
#   'looking',
#   'find',
#   'someone',
#   'special',
#   'think',
#   'initial',
#   'meeting',
#   'chemistry',
#   'important',
#   'lets',
#   'wine',
#   'country',
#   'explore',
#   'new',
#   'area',
#   'try',
#   'newrestaurant',
#   'enjoy',
#   'nice',
#   'glass',
#   'wine',
#   'together',
#   'email',
#   'weeks',
#   'spark',
#   'uponmeeting',
#   'least',
#   'know',
#   'make',
#   'new',
#   'friendshere',
#   'easy',
#   'fun',
#   'easy',
#   'going',
#   'spontaneous',
#   'honest'],
#  ['normal',
#   'people',
#   'one',
#   'know',
#   'verywell',
#   'quick',
#   'bellwether',
#   'youtube',
#   'com',
#   'watch',
#   'feature',
#   'player_embedded',
#   'tynabziknr8',
#   'music2hold',
#   'sliding',
#   'linoleum',
#   'stocking',
#   'feet',
#   'contest',
#   'agree',
#   'keep',
#   'going',
#   'neutral',
#   'fine2',
#   'goofy',
#   'like',
#   'get',
#   'exceedingly',
#   'simple',
#   'woefully',
#   'complicated',
#   'large',
#   'vocabulary',
#   'begin',
#   'spell',
#   'building',
#   'organizing',
#   'people',
#   'creating',
#   'supporting',
#   'promoting',
#   'art',
#   'twirling',
#   'mustache',
#   'everyday',
#   'hope',
#   'put',
#   'effort',
#   'towards',
#   'type',
#   'highminded',
#   'cat',
#   'know',
#   'results',
#   'vary'],
#  ['moved',
#   'cincinnati',
#   'teaching',
#   'privatehigh',
#   'school',
#   'cincy',
#   'working',
#   'start',
#   'redwoodcity',
#   'pretty',
#   'easy',
#   'going',
#   'guy',
#   'enjoy',
#   'simple',
#   'pleasures',
#   'inlife',
#   'watching',
#   'football',
#   'game',
#   'bills',
#   'drinking',
#   'beer',
#   'staying',
#   'late',
#   'discussing',
#   'nothing',
#   'particular',
#   'eating',
#   'icecream',
#   'sundae',
#   'warm',
#   'summer',
#   'day',
#   'etc',
#   'like',
#   'think',
#   'opinions',
#   'challenged',
#   'able',
#   'havepolitical',
#   'religious',
#   'discussions',
#   'debates',
#   'important',
#   'said',
#   'also',
#   'crack',
#   'numerous',
#   'bad',
#   'charlie',
#   'sheen',
#   'puns',
#   'know',
#   'man',
#   'enough',
#   'coke',
#   'kill',
#   'two',
#   'half',
#   'men',
#   'banter',
#   'hilarity',
#   'bro',
#   'culture',
#   'rant',
#   'parishilton',
#   'rise',
#   'fame',
#   'signifies',
#   'decline',
#   'westerncivilization',
#   'open',
#   'minded',
#   'honest',
#   'self',
#   'aware'],
#  ['every',
#   'winter',
#   'work',
#   'bring',
#   'bay',
#   'area',
#   'love',
#   'mild',
#   'weatherhere',
#   'mlooking',
#   'one',
#   'hangout',
#   'activity',
#   'date',
#   'enjoygood',
#   'time',
#   'drama',
#   'summer',
#   'may',
#   'working',
#   'today',
#   'email',
#   'tex',
#   'phone',
#   'make',
#   'contact',
#   'real',
#   'time',
#   'tokeep',
#   'touch'],
#  ['note',
#   'side',
#   'world',
#   'coupleweeks',
#   '_______________well',
#   'seems',
#   'years',
#   'back',
#   'single',
#   'life',
#   'mylong',
#   'term',
#   'albeit',
#   'somewhat',
#   'open',
#   'relationship',
#   'status',
#   'haschanged',
#   'consider',
#   'creative',
#   'artist',
#   'yet',
#   'someone',
#   'uses',
#   'lobes',
#   'originally',
#   'midwest',
#   'moved',
#   'years',
#   'ago',
#   'found',
#   'myhome',
#   'people',
#   'worked',
#   'animation',
#   'modeling',
#   'many',
#   'yearsbut',
#   'prefer',
#   'art',
#   'tangible',
#   'make',
#   'sculpture',
#   'big',
#   'sculpture',
#   'mostly',
#   'metal',
#   'days',
#   'tend',
#   'think',
#   'food',
#   'terms',
#   'ofcolor',
#   'like',
#   'way',
#   'sounds',
#   'look',
#   'feel',
#   'enjoy',
#   'life',
#   'valuespontaneity',
#   'gregarious',
#   'tangential',
#   'silly',
#   'analytical',
#   'andinspiring',
#   'burner',
#   'burningman',
#   'since',
#   'man',
#   'last',
#   'stood',
#   'theground',
#   'value',
#   'creativity',
#   'inspiration',
#   'music',
#   'andscience',
#   'sensuality',
#   'fun',
#   'entp',
#   'according',
#   'tomindtime',
#   'phenomenological',
#   'approach',
#   'thought',
#   'future',
#   'thinkerrather',
#   'past',
#   'present',
#   'thinker'],
#  ['really',
#   'simple',
#   'person',
#   'anaytical',
#   'personality',
#   'ilove',
#   'people',
#   'build',
#   'relationships',
#   'based',
#   'trust',
#   'work',
#   'quitea',
#   'bit',
#   'always',
#   'find',
#   'time',
#   'fun'],
#  ['pretty',
#   'much',
#   'cannot',
#   'bothered',
#   'fill',
#   'willsay',
#   'fun',
#   'warm',
#   'funny',
#   'active',
#   'yet',
#   'lazy',
#   'curious'],
#  ['pretty',
#   'laid',
#   'back',
#   'guy',
#   'currently',
#   'work',
#   'full',
#   'time',
#   'salesengineer',
#   'small',
#   'tech',
#   'startup',
#   'job',
#   'pretty',
#   'amazing',
#   'asi',
#   'lot',
#   'variety',
#   'day',
#   'day',
#   'activities',
#   'get',
#   'totravel',
#   'time',
#   'time',
#   'well',
#   'love',
#   'outdoors',
#   'beingvery',
#   'active',
#   'although',
#   'right',
#   'person',
#   'reallycare',
#   'enjoying',
#   'make',
#   'surethat',
#   'outside',
#   'grind',
#   'hobbies',
#   'include',
#   'playing',
#   'hockey',
#   'hanging',
#   'friends',
#   'traveling',
#   'cooking',
#   'poorly',
#   'hiking',
#   'andgoing',
#   'shows',
#   'pretty',
#   'sarcastic',
#   'person',
#   'definitely',
#   'clickwith',
#   'people',
#   'good',
#   'sense',
#   'humor',
#   'overlysensitive'],
#  ['might',
#   'wondering',
#   'profile',
#   'name',
#   'welli',
#   'love',
#   'burrito',
#   'kinds',
#   'burrito',
#   'cheesy',
#   'lamb',
#   'filled',
#   'veal',
#   'filled',
#   'duck',
#   'filled',
#   'whatever',
#   'care',
#   'give',
#   'agod',
#   'damn',
#   'burrito',
#   'seriously',
#   'though',
#   'love',
#   'food',
#   'inmy',
#   'mouth',
#   'like',
#   'cooking',
#   'waste',
#   'time',
#   'youlike',
#   'cooking',
#   'eating',
#   'gal',
#   'let',
#   'tell',
#   'hate',
#   'vegetarians',
#   'vegans',
#   'swhat',
#   'might',
#   'hottest',
#   'thing',
#   'since',
#   'marilyn',
#   'monroe',
#   'cow',
#   'put',
#   'said',
#   'cow',
#   'mouth',
#   'properlycooked',
#   'course',
#   'ride',
#   'said',
#   'cow',
#   'saidsunset',
#   'make',
#   'money',
#   'might',
#   'wondering',
#   'pay',
#   'allthis',
#   'tasty',
#   'tasty',
#   'food',
#   'one',
#   'word',
#   'murals',
#   'google',
#   'shit',
#   'youdon',
#   'know',
#   'actually',
#   'know',
#   'stop',
#   'readingthis',
#   'immediately',
#   'find',
#   'joe',
#   'shmoe',
#   'tno',
#   'joe',
#   'shmoe',
#   'paint',
#   'murals',
#   'need',
#   'mural',
#   'yourbedroom',
#   'public',
#   'bathroom',
#   'church',
#   'inside',
#   'dogshouse',
#   'problem',
#   'paint',
#   'went',
#   'school',
#   'zoo',
#   'keeping',
#   'zoology',
#   'fancy',
#   'folks',
#   'ended',
#   'paintingmurals',
#   'say',
#   'muhammad',
#   'gives',
#   'gift',
#   'gottarun',
#   'thanks',
#   'muhammad',
#   'thanks',
#   'whole',
#   'hell',
#   'alot',
#   'onto',
#   'things',
#   'like',
#   'fun',
#   'paragraphwhere',
#   'supposed',
#   'tell',
#   'obscure',
#   'music',
#   'andmovies',
#   'neither',
#   'never',
#   'heard',
#   'let',
#   'skipthat',
#   'bullshit',
#   'cut',
#   'right',
#   'chase',
#   'like',
#   'eat',
#   'food',
#   'drinkbeer',
#   'listen',
#   'really',
#   'popular',
#   'music',
#   'everyone',
#   'knows',
#   'everynow',
#   'like',
#   'watch',
#   'movie',
#   'film',
#   'youuptight',
#   'hipsters',
#   'want',
#   'meet',
#   'anyway',
#   'also',
#   'think',
#   'mylittle',
#   'pony',
#   'great',
#   'way',
#   'pass',
#   'time',
#   'saturdayafternoon',
#   'end'],
#  ['east',
#   'bay',
#   'native',
#   'big',
#   'time',
#   'nerd',
#   'highly',
#   'analytical',
#   'hedonistictendencies',
#   'expert',
#   'fields',
#   'cognitive',
#   'dissonance',
#   'language',
#   'andcomputer',
#   'programming',
#   'scuba',
#   'certified',
#   'startup',
#   'founder',
#   'open',
#   'source',
#   'contributor',
#   'probably',
#   'laid',
#   'back',
#   'person',
#   'ofall',
#   'time'],
#  ['hey',
#   'healthy',
#   'guy',
#   'health',
#   'everything',
#   'possible',
#   'love',
#   'run',
#   'workout',
#   'hike',
#   'regularly',
#   'aminto',
#   'physical',
#   'activities',
#   'well',
#   'love',
#   'hang',
#   'andbe',
#   'spontaneous'],
#  ['laid', 'back', 'guy', 'hoping', 'meet', 'really', 'nice', 'ladies'],
#  ['tom',
#   'tall',
#   'tom',
#   'funny',
#   'tom',
#   'creative',
#   'bright',
#   'tom',
#   'isloyal',
#   'dependable',
#   'loving',
#   'tom',
#   'good',
#   'job',
#   'drives',
#   'himcrazy',
#   'tom',
#   'cheat',
#   'tom',
#   'real',
#   'quiet',
#   'timesbut',
#   'let',
#   'freak',
#   'way',
#   'tom',
#   'works',
#   'atv',
#   'station',
#   'plays',
#   'bass',
#   'rock',
#   'band',
#   'tom',
#   'lot',
#   'offree',
#   'time',
#   'throwing',
#   'internet',
#   'see',
#   'hecan',
#   'meet',
#   'someone',
#   'special',
#   'share',
#   'life'],
#  ['born',
#   'raised',
#   'socal',
#   'moved',
#   'bay',
#   'area',
#   'forschool',
#   'kind',
#   'stuck',
#   'around',
#   'love',
#   'socal',
#   'thebay',
#   'grew',
#   'haha',
#   'visual',
#   'artist',
#   'currentlyworking',
#   'dreamworks',
#   'animation',
#   'pixar',
#   'toystory',
#   'haha',
#   'generally',
#   'positive',
#   'good',
#   'humored',
#   'guy',
#   'try',
#   'athleticas',
#   'possible',
#   'enjoy',
#   'taking',
#   'swings',
#   'batting',
#   'cages',
#   'snowboarding',
#   'wake',
#   'boarding',
#   'send',
#   'message',
#   'want',
#   'know',
#   'try',
#   'respondthough',
#   'sometimes',
#   'forget',
#   'check',
#   'messages',
#   'sorry',
#   'inadvance',
#   'hear',
#   'back',
#   'right',
#   'away'],
#  ['born',
#   'raised',
#   'rural',
#   'missouri',
#   'educated',
#   'boston',
#   'andbaltimore',
#   'love',
#   'open',
#   'spaces',
#   'urban',
#   'places',
#   'speakwith',
#   'twang',
#   'anymore',
#   'except',
#   'back',
#   'home',
#   'notintentional',
#   'swear',
#   'unusually',
#   'high',
#   'tolerance',
#   'perhapseven',
#   'appreciation',
#   'country',
#   'music',
#   'itunes',
#   'collectionspans',
#   'musical',
#   'spectrum',
#   'politically',
#   'liberal',
#   'highschool',
#   'classmate',
#   'postings',
#   'sometimes',
#   'make',
#   'cringe',
#   'iunderstand',
#   'good',
#   'people',
#   'huge',
#   'fan',
#   'rei',
#   'iavoid',
#   'shopping',
#   'wal',
#   'mart',
#   'seen',
#   'smalltown',
#   'economy',
#   'prefer',
#   'take',
#   'subaru',
#   'dirtroads',
#   'learned',
#   'love',
#   'challenge',
#   'squeezing',
#   'theonly',
#   'available',
#   'parallel',
#   'parking',
#   'space',
#   'moved',
#   'bay',
#   'area',
#   'nine',
#   'years',
#   'ago',
#   'start',
#   'first',
#   'real',
#   'job',
#   'count',
#   'high',
#   'school',
#   'summer',
#   'grill',
#   'boy',
#   'atmcdonald',
#   'mentoring',
#   'graduate',
#   'students',
#   'lab',
#   'orteaching',
#   'classroom',
#   'enjoy',
#   'outdoorshiking',
#   'biking',
#   'fly',
#   'fishing',
#   'skiing',
#   'hanging',
#   'dog',
#   'ilove',
#   'watching',
#   'films',
#   'going',
#   'concerts',
#   'plays',
#   'keeping',
#   'fit',
#   'byrunning',
#   'road',
#   'races',
#   'sixteen',
#   'half',
#   'marathons',
#   'far',
#   'enjoy',
#   'goodfood',
#   'wine',
#   'cherish',
#   'good',
#   'conversation',
#   'try',
#   'read',
#   'much',
#   'asi',
#   'though',
#   'sometimes',
#   'best',
#   'intentions',
#   'limited',
#   'aquick',
#   'excursion',
#   'new',
#   'yorker',
#   'whatever',
#   'displayin',
#   'grocery',
#   'store',
#   'aisle',
#   'handed',
#   'mysister',
#   'roland',
#   'brushing',
#   'piano',
#   'playing',
#   'alsolike',
#   'cook',
#   'others',
#   'especially'],
#  ['okay',
#   'know',
#   'checked',
#   'pictures',
#   'back',
#   'formore',
#   'great',
#   'going',
#   'take',
#   'dog',
#   'walk',
#   'findout',
#   'little',
#   'enjoy',
#   'shoot',
#   'message',
#   'orwink',
#   'whatever',
#   'done',
#   'get',
#   'know',
#   'eachother',
#   'want',
#   'laugh',
#   'loud',
#   'come',
#   'meet',
#   'jokes',
#   'set',
#   'yourolling',
#   'floor',
#   'eyes',
#   'legs',
#   'make',
#   'stand',
#   'whatfollows',
#   'list',
#   'smile',
#   'set',
#   'everything',
#   'even',
#   'yourmood'],
#  ['socially',
#   'awkward',
#   'give',
#   'drinks',
#   'think',
#   'havea',
#   'good',
#   'laugh',
#   'hate',
#   'read',
#   'profiles',
#   'feels',
#   'like',
#   'havebeen',
#   'copied',
#   'paste',
#   'either',
#   'read',
#   'one',
#   'many',
#   'thesame',
#   'ones',
#   'recently',
#   'joined',
#   'meet',
#   'crew',
#   'going',
#   'try',
#   'afew',
#   'mixer',
#   'running',
#   'group',
#   'hopefully',
#   'meet',
#   'newfaces',
#   'friends',
#   'fate',
#   'pushing',
#   'trying',
#   'pretty',
#   'goodstart',
#   'let',
#   'start',
#   'really',
#   'expect',
#   'toread',
#   'whole',
#   'profile',
#   'got',
#   'far',
#   'kudos',
#   'handclap'],
#  ['way',
#   'los',
#   'angeles',
#   'portland',
#   'landed',
#   'sanfrancisco',
#   'cold',
#   'heading',
#   'san',
#   'diego',
#   'nextweek',
#   'update',
#   'back',
#   'san',
#   'francisco',
#   'seem',
#   'get',
#   'away'],
#  ['really',
#   'point',
#   'summary',
#   'think',
#   'anyoneactually',
#   'reads',
#   'part',
#   'look',
#   'pictures',
#   'either',
#   'move',
#   'think',
#   'cute',
#   'enough',
#   'read',
#   'myemail',
#   'return',
#   'message',
#   'viewing',
#   'pics',
#   'see',
#   'ifi',
#   'cute',
#   'enough',
#   'come',
#   'know',
#   'truth',
#   'guys',
#   'generally',
#   'put',
#   'effort',
#   'online',
#   'becauseit',
#   'goes',
#   'nowhere',
# ...
#   'take',
#   'slow',
#   'andreally',
#   'slow',
#   'stretched',
#   'years',
#   'typically',
#   'prefer'],
#  ['curious',
#   'smart',
#   'individualistic',
#   'intellectual',
#   'active',
#   'andprincipled',
#   'dry',
#   'sense',
#   'humor',
#   'appreciation',
#   'theabsurd'],
#  ['moved',
#   'years',
#   'ago',
#   'way',
#   'boston',
#   'like',
#   'vinyl',
#   'art',
#   'wine',
#   'movies',
#   'comics',
#   'digital',
#   'art',
#   'yerba',
#   'matte',
#   'tea',
#   'hateon',
#   'things',
#   'enjoy',
#   'retrospect',
#   'rather',
#   'listento',
#   'others',
#   'talk',
#   'also',
#   'like',
#   'animals'],
#  ['quick',
#   'overview',
#   'moved',
#   'oakland',
#   'almost',
#   'years',
#   'ago',
#   'tallahassee',
#   'welsh',
#   'corgi',
#   'named',
#   'science',
#   'tend',
#   'make',
#   'art',
#   'consume',
#   'ever',
#   'dancing',
#   'cause',
#   'time',
#   'think',
#   'musicisterrible',
#   'say',
#   'dance',
#   'favoritebands',
#   'love',
#   'cooking',
#   'except',
#   'really',
#   'would',
#   'like',
#   'people',
#   'hang',
#   'way',
#   'hardertomake',
#   'friends',
#   'late',
#   '20s',
#   'outside',
#   'college',
#   'townthere',
#   'save',
#   'later'],
#  ['midwestern',
#   'boy',
#   'design',
#   'although',
#   'like',
#   'football',
#   'nascar',
#   'football',
#   'chewing',
#   'tabacco',
#   'souping',
#   'truck',
#   'ordrinking',
#   'beer',
#   'got',
#   'hell',
#   'outof',
#   'fast',
#   'possible',
#   'since',
#   'leaving',
#   'lived',
#   'mexico',
#   'peru',
#   'spain',
#   'texas',
#   'oregon',
#   'finally',
#   'bay',
#   'area',
#   'since',
#   'moving',
#   'started',
#   'profit',
#   'play',
#   'lot',
#   'ofmusic',
#   'matter',
#   'fact',
#   'two',
#   'intertwined',
#   'also',
#   'volunteer',
#   'fora',
#   'local',
#   'college',
#   'radio',
#   'station',
#   'crazy',
#   'busy',
#   'majorbeliever',
#   'collective',
#   'environments',
#   'makes',
#   'dopey',
#   'grin',
#   'surfing',
#   'camping',
#   'old',
#   'time',
#   'slang',
#   'music',
#   'psychedelics',
#   'collecting',
#   'oldhauntedfurniture',
#   'records',
#   'books',
#   'taxidermy',
#   'food',
#   'getting',
#   'dirty',
#   'silent',
#   'classic',
#   'badmovies',
#   'stanford',
#   'theatre',
#   'flea',
#   'farmers',
#   'markets',
#   'selfsufficient',
#   'living',
#   'alot',
#   'crapisn',
#   'kind',
#   'weird',
#   'okcupid',
#   'asks',
#   'income',
#   'levels',
#   'think',
#   'favorite',
#   'part',
#   'filling',
#   'profile',
#   'mnot',
#   'filling',
#   'anymore'],
#  ['let',
#   'put',
#   'smoking',
#   'jacket',
#   'head',
#   'den',
#   'brandysnifting',
#   'ahhh',
#   'yes',
#   'like',
#   'lapel',
#   'yes',
#   'pureguatamalan',
#   'rainforestchipmunk',
#   'follow',
#   'way',
#   'less',
#   'want',
#   'hearmore',
#   'lexicographer',
#   'etc',
#   'stuff'],
#  ['recently',
#   'moved',
#   'north',
#   'bay',
#   'exploring',
#   'loving',
#   'area',
#   'musically',
#   'inclined',
#   'love',
#   'arts',
#   'general',
#   'good',
#   'food',
#   'obscure',
#   'aspects',
#   'life',
#   'always',
#   'intriguing'],
#  ['say',
#   'hailing',
#   'texas',
#   'longhorns',
#   'icame',
#   'cali',
#   'well',
#   'decade',
#   'ago',
#   'looking',
#   'little',
#   'sunshinein',
#   'life',
#   'definitely',
#   'understand',
#   'people',
#   'come',
#   'tocalifornia',
#   'never',
#   'leave',
#   'like',
#   'well',
#   'always',
#   'liked',
#   'cook',
#   'mostly',
#   'southindian',
#   'comfort',
#   'food',
#   'read',
#   'love',
#   'amazon',
#   'kindle',
#   'ipad',
#   'listen',
#   'music',
#   'like',
#   'something',
#   'time',
#   'gamble',
#   'really',
#   'bet',
#   'addiction',
#   'watch',
#   'movies',
#   'favorite',
#   'hobby',
#   'call',
#   'travel',
#   'loveto',
#   'travel',
#   'far',
#   'places',
#   'meet',
#   'new',
#   'people',
#   'wherever',
#   'traveling',
#   'lets',
#   'practice',
#   'another',
#   'favorite',
#   'hobby',
#   'photography',
#   'anything',
#   'though',
#   'love',
#   'hanging',
#   'friends',
#   'even',
#   'anything',
#   'particular',
#   'like',
#   'well',
#   'think',
#   'one',
#   'word',
#   'describes',
#   'bestis',
#   'happy',
#   'coincidentally',
#   'also',
#   'name',
#   'cantranslate',
#   'one',
#   'indian',
#   'languages',
#   'like',
#   'fun',
#   'love',
#   'laugh',
#   'attitude',
#   'life',
#   'pretty',
#   'easy',
#   'going',
#   'malso',
#   'apparently',
#   'parenthetical',
#   'profile',
#   'butconversationally',
#   'also',
#   'know',
#   'need',
#   'stop',
#   'looking',
#   'someone',
#   'first',
#   'foremost',
#   'lookingfor',
#   'friend',
#   'strong',
#   'believer',
#   'friendship',
#   'first',
#   'sight',
#   'said',
#   'favorite',
#   'people',
#   'open',
#   'minded',
#   'well',
#   'versed',
#   'inthe',
#   'art',
#   'conversation',
#   'intelligent',
#   'caring',
#   'fun',
#   'love',
#   'travel',
#   'borrow',
#   'phrase',
#   'friend',
#   'mine',
#   'know',
#   'good',
#   'way',
#   'towaste',
#   'afternoon'],
#  ['friend',
#   'called',
#   'cross',
#   'aziz',
#   'ansari',
#   'steve',
#   'jobs',
#   'maybe',
#   'teensy',
#   'stretch',
#   'take',
#   'bit',
#   'year',
#   'moved',
#   'toronto',
#   'dig',
#   'westcoast',
#   'vibe',
#   'amazing',
#   'food',
#   'coffee',
#   'miss',
#   'big',
#   'city',
#   'hustlesometimes',
#   'want',
#   'one',
#   'thing',
#   'girl',
#   'effortless',
#   'conversation',
#   'feellike',
#   'connect',
#   'everything',
#   'else',
#   'easy'],
#  ['guy',
#   'sitting',
#   'cushy',
#   'bench',
#   'bookstore',
#   'reading',
#   'onthe',
#   'road',
#   'hours',
#   'dear',
#   'friends',
#   'bookstore',
#   'peace',
#   'brothers',
#   'also',
#   'guy',
#   'walking',
#   'mission',
#   'streetpretty',
#   'much',
#   'shouting',
#   'friend',
#   'camera',
#   'work',
#   'earlyperiod',
#   'fellini',
#   'could',
#   'think',
#   'average',
#   'nerd',
#   'thepark',
#   'except',
#   'intellectualbuzz',
#   'one',
#   'thing',
#   'funny',
#   'observant',
#   'little',
#   'bit',
#   'nuts',
#   'havea',
#   'trenchant',
#   'wit',
#   'plenty',
#   'skepticism',
#   'towards',
#   'people',
#   'power',
#   'afabulist',
#   'idealist',
#   'cynic',
#   'usually',
#   'time',
#   'love',
#   'take',
#   'different',
#   'ideas',
#   'put',
#   'one',
#   'basket',
#   'mixing',
#   'art',
#   'politics',
#   'science',
#   'imagination',
#   'tradition',
#   'withcuriosity',
#   'progress',
#   'change',
#   'also',
#   'stunned',
#   'silence',
#   'grateful',
#   'forthat',
#   'rodin',
#   'sculpture',
#   'ancient',
#   'tree',
#   'redwoodforest',
#   'incredible',
#   'solo',
#   'legendary',
#   'jazz',
#   'bassist',
#   'sometimes',
#   'get',
#   'lost',
#   'big',
#   'picture',
#   'world',
#   'ideas',
#   'snapsup',
#   'attention',
#   'like',
#   'flashy',
#   'lure',
#   'need',
#   'reminder',
#   'thatdetails',
#   'matter',
#   'story',
#   'called',
#   'style',
#   'born',
#   'reader',
#   'terrific',
#   'listener',
#   'things',
#   'aliving',
#   'write',
#   'poetry',
#   'philosophical',
#   'fiction',
#   'livedabroad',
#   'else',
#   'npr',
#   'junkie',
#   'avoice',
#   'crush',
#   'terry',
#   'gross',
#   'excellent',
#   'cook',
#   'thebattle',
#   'scars',
#   'prove',
#   'every',
#   'page',
#   'cookbook',
#   'splatteredwith',
#   'something',
#   'kind',
#   'animals',
#   'doubt',
#   'err',
#   'onthe',
#   'side',
#   'reality',
#   'humble',
#   'necessity',
#   'mayhave',
#   'architectonic',
#   'notions',
#   'meaning',
#   'history',
#   'yet',
#   'takethe',
#   'bus',
#   'love',
#   'america',
#   'flannery',
#   'connor',
#   'edward',
#   'hopper',
#   'tom',
#   'waits',
#   'also',
#   'new',
#   'city',
#   'work',
#   'progress'],
#  ['easy',
#   'going',
#   'hard',
#   'working',
#   'person',
#   'still',
#   'finds',
#   'time',
#   'afterwork',
#   'smoke',
#   'little',
#   'drink',
#   'couple',
#   'beers',
#   'know',
#   'thatjust',
#   'single',
#   'get',
#   'old',
#   'eventually',
#   'somesay',
#   'already',
#   'point',
#   'thinking',
#   'aboutsettling',
#   'total',
#   'relationships',
#   'life',
#   'inever',
#   'felt',
#   'important',
#   'like',
#   'honestly',
#   'lost',
#   'virginitybecause',
#   'friends',
#   'made',
#   'seem',
#   'like',
#   'big',
#   'deal',
#   'justpulled',
#   'female',
#   'yeah',
#   'get',
#   'way'],
#  ['laid',
#   'back',
#   'person',
#   'part',
#   'might',
#   'say',
#   'amincapable',
#   'stressing',
#   'kind',
#   'nerd',
#   'even',
#   'though',
#   'oneexpects'],
#  ['maia', 'john', 'couple', 'looking', 'new', 'friendsto', 'hang'],
#  ['bay',
#   'area',
#   'native',
#   'spent',
#   'entire',
#   'live',
#   'living',
#   'exceptfor',
#   'year',
#   'grad',
#   'school',
#   'outdoors',
#   'type',
#   'asi',
#   'like',
#   'play',
#   'golf',
#   'weekends',
#   'jogging',
#   'around',
#   'thelake',
#   'trying',
#   'find',
#   'special',
#   'someone',
#   'life',
#   'willingto',
#   'give',
#   'site',
#   'try',
#   'lose'],
#  ['difficult',
#   'describe',
#   'identity',
#   'tstatic',
#   'flexible',
#   'adaptable',
#   'circumstance',
#   'professional',
#   'personal',
#   'work',
#   'process',
#   'somestrengths',
#   'pretty',
#   'bright',
#   'creative',
#   'willing',
#   'take',
#   'risks',
#   'see',
#   'things',
#   'differently',
#   'people',
#   'though',
#   'canappreciate',
#   'range',
#   'perspectives',
#   'weaknesses',
#   'tendto',
#   'loyal',
#   'fault',
#   'good',
#   'getting',
#   'need',
#   'wantin',
#   'relationships'],
#  ['sea',
#   'till',
#   'july',
#   'bit',
#   'type',
#   'guy',
#   'legitimately',
#   'enjoys',
#   'company',
#   'women',
#   'open',
#   'doors',
#   'pull',
#   'chairs',
#   'pay',
#   'dinner',
#   'things',
#   'dexpect',
#   'pretty',
#   'old',
#   'school',
#   'knowi',
#   'traveler',
#   'countries',
#   'last',
#   'years',
#   'whichis',
#   'mainly',
#   'result',
#   'year',
#   'school',
#   'traveled',
#   'western',
#   'europe',
#   'vagabond',
#   'style',
#   'hope',
#   'make',
#   'australia',
#   'next',
#   'havethe',
#   'best',
#   'accent',
#   'ever',
#   'favorite',
#   'color',
#   'blue',
#   'awesome',
#   'pair',
#   'bluesuede',
#   'shoes',
#   'need',
#   'least',
#   'spontaneous',
#   'adventure',
#   'point',
#   'time',
#   'one',
#   'favorite',
#   'things',
#   'head',
#   'bike',
#   'makesome',
#   'random',
#   'turns',
#   'always',
#   'end',
#   'meeting',
#   'new',
#   'people',
#   'findsomething',
#   'fun',
#   'jumped',
#   'foot',
#   'cliff',
#   'intowater',
#   'hiked',
#   'miles',
#   'one',
#   'day',
#   'biked',
#   'miles',
#   'one',
#   'day',
#   'sailed',
#   'across',
#   'pacific',
#   'like',
#   'kinds',
#   'thingsnot',
#   'really',
#   'sure',
#   'kind',
#   'girl',
#   'would',
#   'want',
#   'life',
#   'thispoint',
#   'even',
#   'want',
#   'one',
#   'getting',
#   'ialready',
#   'found',
#   'girl',
#   'could',
#   'make',
#   'iteasier',
#   'descriptive',
#   'words',
#   'spontaneous',
#   'adventurous',
#   'romantic',
#   'positive',
#   'confident',
#   'funny',
#   'intellectual',
#   'honest',
#   'outgoing',
#   'joke',
#   'bear',
#   'walks',
#   'bar',
#   'says',
#   'want',
#   'bourbonand',
#   'coke',
#   'bartender',
#   'asks',
#   'huge',
#   'pause',
#   'bear',
#   'says',
#   'life',
#   'yes',
#   'know',
#   'want',
#   'lol',
#   'blame'],
#  ['short',
#   'like',
#   'math',
#   'psychology',
#   'dancing',
#   'sharingmusic',
#   'climbing',
#   'growth',
#   'mindset',
#   'getting',
#   'bottom',
#   'disagreements',
#   'empirical',
#   'matters',
#   'flippant',
#   'ridiculous',
#   'nonsense',
#   'understanding',
#   'values',
#   'emotionsof',
#   'people',
#   'around',
#   'long',
#   'talks',
#   'outdoors',
#   'especially',
#   'conversation',
#   'eithergoes',
#   'somewhere',
#   'happens',
#   'tree',
#   'necessarily',
#   'yes',
#   'necessarily',
#   'enfj',
#   'takes',
#   'taking',
#   'things',
#   'tooseriously',
#   'pretty',
#   'seriously',
#   'except',
#   'disagree',
#   'normatively',
#   'thef',
#   'axis',
#   'ask',
#   'favorite',
#   'people',
#   'cantransition',
#   'seamlessly',
#   'intellectual',
#   'flippantridiculous',
#   'nonsense',
#   'climbing',
#   'library',
#   'sideways',
#   'alsoreally',
#   'like',
#   'people',
#   'find',
#   'happiness',
#   'others',
#   'contagious',
#   'happy',
#   'want',
#   'show',
#   'damn',
#   'long',
#   'grew',
#   'canada',
#   'looking',
#   'back',
#   'pretty',
#   'trippy',
#   'roughly',
#   'half',
#   'meat',
#   'ate',
#   'stuff',
#   'family',
#   'fished',
#   'andhunted',
#   'built',
#   'house',
#   'trees',
#   'dad',
#   'cut',
#   'downand',
#   'pulled',
#   'forest',
#   'sawed',
#   'saw',
#   'mill',
#   'builtwith',
#   'grandfather',
#   'okay',
#   'womb',
#   'momhelped',
#   'child',
#   'played',
#   'ice',
#   'hockey',
#   'frozen',
#   'atlanticharbor',
#   'front',
#   'house',
#   'kids',
#   'village',
#   'onthe',
#   'weekends',
#   'ice',
#   'fish',
#   'make',
#   'huts',
#   'tree',
#   'branches',
#   'tosleep',
#   'stay',
#   'warm',
#   'slow',
#   'burning',
#   'fire',
#   'tdestroy',
#   'hut',
#   'live',
#   'california',
#   'love',
#   'also',
#   'lived',
#   'rome',
#   'forsix',
#   'months',
#   'awesome',
#   'bay',
#   'wins',
#   'still',
#   'going',
#   'backto',
#   'visit',
#   'canada',
#   'twice',
#   'year',
#   'pretty',
#   'fun',
#   'canadian',
#   'hasthe',
#   'desirable',
#   'side',
#   'effect',
#   'whoever',
#   'marries',
#   'gets',
#   'freeuniversal',
#   'health',
#   'care',
#   'handy',
#   'old',
#   'used',
#   'play',
#   'lot',
#   'musical',
#   'instruments',
#   'handinjury',
#   'never',
#   'got',
#   'back',
#   'hours',
#   'day',
#   'serious',
#   'mydefault',
#   'passive',
#   'experience',
#   'music',
#   'still',
#   'revise',
#   'andmentally',
#   'interject',
#   'parts',
#   'though',
#   'makes',
#   'listening',
#   'fun',
#   'far',
#   'beliefs',
#   'let',
#   'wax',
#   'earnest',
#   'two',
#   'paragraphs',
#   'ibelieve',
#   'physical',
#   'world',
#   'things',
#   'amenable',
#   'scientificstudy',
#   'find',
#   'boring',
#   'unromantic',
#   'find',
#   'itbeautiful',
#   'would',
#   'believe',
#   'might',
#   'questionsabout',
#   'human',
#   'soul',
#   'people',
#   'wrong',
#   'well',
#   'thereare',
#   'good',
#   'news',
#   'soul',
#   'source',
#   'seat',
#   'humanwill',
#   'conscience',
#   'morality',
#   'thought',
#   'emotion',
#   'really',
#   'doesexist',
#   'found',
#   'bad',
#   'news',
#   'immortal',
#   'butthere',
#   'good',
#   'news',
#   'made',
#   'neurons',
#   'far',
#   'cantell',
#   'runs',
#   'physics',
#   'magic',
#   'yep',
#   'soul',
#   'regularmatter',
#   'think',
#   'pretty',
#   'awesome',
#   'course',
#   'science',
#   'could',
#   'wrong',
#   'themost',
#   'reliable',
#   'procedure',
#   'forming',
#   'accurate',
#   'beliefs',
#   'anybelief',
#   'forming',
#   'tradition',
#   'unlikely',
#   'far',
#   'cantell',
#   'different',
#   'truths',
#   'world',
#   'works',
#   'fordifferent',
#   'people',
#   'one',
#   'staring',
#   'ithink',
#   'cozy',
#   'like',
#   'sitting',
#   'around',
#   'campfire',
#   'means',
#   'canstrive',
#   'together',
#   'species',
#   'find',
#   'objectively',
#   'increasinglyaccurate',
#   'view',
#   'things',
#   'work',
#   'ever',
#   'thought',
#   'thataccepting',
#   'falsehoods',
#   'way',
#   'people',
#   'tolerant',
#   'ofeach',
#   'beliefs',
#   'patience',
#   'diligence',
#   'reall',
#   'wrong',
#   'tons',
#   'stuff',
#   'let',
#   'compare',
#   'notes',
#   'get',
#   'itright',
#   'join',
#   'campfire',
#   'let',
#   'dance',
#   'party',
#   'radio',
#   'like',
#   'hating',
#   'pop',
#   'culture',
#   'outof',
#   'style',
#   'seriously',
#   'need',
#   'dancing'],
#  ['bay',
#   'area',
#   'native',
#   'recent',
#   'resident',
#   'college',
#   'grad',
#   'nerd',
#   'formercopy',
#   'editor',
#   'feminist',
#   'poor',
#   'typist',
#   'dangerous',
#   'amateur',
#   'rapper'],
#  ['construction',
#   'good',
#   'idea',
#   'time',
#   'mnot',
#   'tech',
#   'savvy',
#   'like',
#   'food',
#   'eat',
#   'withyour',
#   'hands',
#   'like',
#   'graff',
#   'writers',
#   'mess',
#   'city',
#   'havegood',
#   'potential',
#   'energy',
#   'like',
#   'high',
#   'end',
#   'clothing',
#   'saysabout',
#   'day',
#   'age',
#   'live',
#   'womans',
#   'dress',
#   'form',
#   'playwith',
#   'time',
#   'time',
#   'movies',
#   'every',
#   'toconcerts',
#   'every',
#   'like',
#   'dub',
#   'electro',
#   'house',
#   'andhardcore',
#   'hip',
#   'hop',
#   'wordsmith',
#   'given',
#   'moment',
#   'likecoining',
#   'phrases',
#   'right',
#   'word',
#   'eludes',
#   'like',
#   'dance',
#   'laugh',
#   'time',
#   'usually',
#   'means',
#   'agood',
#   'time',
#   'really',
#   'working',
#   'like',
#   'mean',
#   'fore',
#   'play',
#   'andmaybe',
#   'learning',
#   'sex',
#   'laugh',
#   'partner',
#   'enjoy',
#   'hookah',
#   'bars',
#   'laughing',
#   'like',
#   'messing',
#   'clean',
#   'upwhile',
#   'laughing',
#   'would',
#   'like',
#   'think',
#   'decent',
#   'artist',
#   'mixmedia',
#   'working',
#   'wood',
#   'moment',
#   'going',
#   'great',
#   'film',
#   'maker',
#   'one',
#   'day',
#   'mantra',
#   'everand',
#   'day',
#   'ahhh',
#   'else',
#   'west',
#   'african',
#   'dance',
#   'falls',
#   'dance',
#   'like',
#   'cook',
#   'orbe',
#   'helpful',
#   'kitchen',
#   'general',
#   'like',
#   'falling',
#   'asleep',
#   'awoman',
#   'happy',
#   'fall',
#   'asleep',
#   'druel',
#   'pillows',
#   'sometimes',
#   'known',
#   'snore',
#   'andlook',
#   'work',
#   'things',
#   'get',
#   'tuff',
#   'think',
#   'going',
#   'let',
#   'hairgrown',
#   'late',
#   'water',
#   'snacks'],
#  ['graduated',
#   'berkeley',
#   'currently',
#   'med',
#   'school',
#   'love',
#   'adventureand',
#   'novelty',
#   'happy',
#   'balanced',
#   'dont',
#   'enough',
#   'time',
#   'getout',
#   'meet',
#   'people',
#   'sooooo',
#   'ladies',
#   'gentle'],
#  ...]

# %%
bigram = gensim.models.Phrases(texts)
texts = [bigram[line] for line in texts]

# %%
texts
# Out:
# [['would',
#   'love',
#   'think',
#   'kind',
#   'intellectual',
#   'either',
#   'dumbest',
#   'smart',
#   'guy',
#   'smartest',
#   'dumb',
#   'guy',
#   'say',
#   'ican',
#   'tell_difference',
#   'love',
#   'talk',
#   'ideas',
#   'concepts',
#   'iforge',
#   'odd',
#   'metaphors',
#   'instead',
#   'reciting',
#   'cliches',
#   'like',
#   'thesimularities',
#   'friend_mine',
#   'house',
#   'underwatersalt',
#   'mine',
#   'favorite',
#   'word',
#   'salt',
#   'way',
#   'weird',
#   'choice',
#   'iknow',
#   'things',
#   'life',
#   'better',
#   'metaphors',
#   'seek',
#   'tomake',
#   'little',
#   'better',
#   'everyday',
#   'productively',
#   'lazyway',
#   'got_tired',
#   'tying',
#   'shoes',
#   'considered',
#   'hiring',
#   'five',
#   'yearold',
#   'would_probably',
#   'tie',
#   'shoes',
#   'decided',
#   'toonly',
#   'wear',
#   'leather',
#   'shoes',
#   'dress',
#   'shoes',
#   'love',
#   'really',
#   'serious',
#   'really',
#   'deep_conversations',
#   'aboutreally',
#   'silly',
#   'stuff',
#   'willing',
#   'snap',
#   'alight',
#   'hearted',
#   'rant',
#   'kiss',
#   'funny',
#   'youhave',
#   'able',
#   'make_laugh',
#   'able',
#   'bend',
#   'spoonswith',
#   'mind',
#   'telepathically',
#   'make_smile',
#   'stillat',
#   'work',
#   'love',
#   'life',
#   'cool',
#   'letting',
#   'thewind',
#   'blow',
#   'extra_points',
#   'reading',
#   'guessing',
#   'myfavorite',
#   'video_game',
#   'hints',
#   'given',
#   'yet',
#   'lastly',
#   'agood',
#   'attention_span'],
#  ['work', 'library', 'school'],
#  ['australian',
#   'living_san',
#   'francisco',
#   'hold',
#   'thatagainst',
#   'spend_days',
#   'trying',
#   'build',
#   'cool_stuff',
#   'formy',
#   'company',
#   'speak_mandarin',
#   'known',
#   'bust',
#   'outchinese',
#   'songs',
#   'karaoke',
#   'pretty',
#   'cheeky',
#   'someone',
#   'asked',
#   'ifthat',
#   'meant',
#   'something',
#   'arse',
#   'find',
#   'reallyfunny',
#   'little',
#   'oddball',
#   'wild',
#   'imagination',
#   'like',
#   'think',
#   'ofthe',
#   'improbable',
#   'reasons',
#   'people',
#   'things',
#   'fun',
#   'ilove',
#   'laugh',
#   'look',
#   'reasons',
#   'occasionally',
#   'getsme',
#   'trouble',
#   'people',
#   'think',
#   'laughing',
#   'sometimesi',
#   'often',
#   'laughing',
#   'entrepreneur',
#   'like',
#   'everyone_else',
#   'seems',
#   'lovewhat',
#   'enjoy',
#   'parties',
#   'downtime',
#   'equal',
#   'measure',
#   'intelligence',
#   'really',
#   'turns',
#   'love',
#   'people',
#   'teach',
#   'menew',
#   'things'],
#  ['names',
#   'jake',
#   'creative',
#   'guy',
#   'look',
#   'others',
#   'easy_going',
#   'practical',
#   'many',
#   'hang',
#   'ups',
#   'iappreciate',
#   'life',
#   'try',
#   'live',
#   'fullest',
#   'sober',
#   'andhave',
#   'past_years',
#   'love',
#   'music',
#   'play_guitar',
#   'like',
#   'tons',
#   'different',
#   'bands',
#   'man',
#   'artist',
#   'love',
#   'paint_draw',
#   'etc',
#   'love',
#   'creativepeople',
#   'got',
#   'say',
#   'big',
#   'internet_dating',
#   'cant',
#   'reallyget',
#   'earnest',
#   'impression',
#   'anyone',
#   'polished',
#   'paragraphs',
#   'see',
#   'never',
#   'know'],
#  ['born',
#   'wisconsin',
#   'grew',
#   'iowa',
#   'moved',
#   'californiathree',
#   'years_ago',
#   'combination',
#   'work',
#   'opportunity',
#   'justwanting',
#   'live',
#   'took',
#   'couple_years',
#   'get',
#   'thepeninsula',
#   'glad',
#   'eventually',
#   'got',
#   'passionate',
#   'aboutpeople',
#   'wide_variety',
#   'interests',
#   'talents',
#   'also',
#   'continually',
#   'learning',
#   'example',
#   'mlearning',
#   'recently',
#   'result',
#   'spending',
#   'timegrowing',
#   'college',
#   'last_five',
#   'years',
#   'focusing',
#   'ongrowing',
#   'deep',
#   'relationship',
#   'skills',
#   'good',
#   'ipreviously',
#   'thought',
#   'initializing',
#   'friendships_relationships',
#   'iguess',
#   'bad_thing',
#   'since',
#   'first_impression',
#   'thingonly',
#   'really',
#   'happens',
#   'person',
#   'result',
#   'love',
#   'friends',
#   'got',
#   'lot',
#   'deep',
#   'friendships',
#   'know',
#   'much',
#   'richer',
#   'friendship',
#   'get',
#   'getsdeeper',
#   'passionate',
#   'music',
#   'play_guitar',
#   'write_songs',
#   'lessnow',
#   'write',
#   'plays',
#   'want',
#   'learnfrench',
#   'asl',
#   'pretty',
#   'good',
#   'amateur',
#   'ballroom',
#   'dancer',
#   'cando',
#   'almost_everything',
#   'moderately',
#   'well',
#   'seriously',
#   'joke',
#   'lovebright',
#   'ties',
#   'shoes',
#   'jacket',
#   'jeans',
#   'person',
#   'absolutelylove',
#   'figuring',
#   'people',
#   'tick',
#   'think',
#   'pretty_cool',
#   'wishmore',
#   'people',
#   'would',
#   'patient',
#   'enough',
#   'take',
#   'time',
#   'seethat',
#   'every',
#   'friend',
#   'ever',
#   'say',
#   'nothing',
#   'like',
#   'anyone_else',
#   'idon',
#   'come',
#   'like',
#   'anyone_else',
#   'person',
#   'proudof'],
#  ['moved_bay',
#   'area',
#   'austin',
#   'originally',
#   'fromlouisiana',
#   'audio',
#   'programming',
#   'video_games',
#   'juststarted',
#   'game',
#   'studio',
#   'yes',
#   'bit',
#   'nerdyprogrammer',
#   'stamped',
#   'across',
#   'forehead',
#   'idon',
#   'even',
#   'really',
#   'play_video',
#   'games',
#   'often',
#   'actuallycreate',
#   'play',
#   'music',
#   'way',
#   'often',
#   'spare_time',
#   'starting',
#   'new',
#   'life',
#   'really',
#   'excited',
#   'ionly',
#   'knew',
#   'one',
#   'person',
#   'area',
#   'moved',
#   'tworried',
#   'always',
#   'make',
#   'friends',
#   'pretty_quickly',
#   'every',
#   'city',
#   'velived',
#   'made',
#   'least',
#   'life',
#   'long',
#   'friends',
#   'definitelylooking',
#   'thing',
#   'easy',
#   'get_along',
#   'kind_person',
#   'always',
#   'try',
#   'toavoid',
#   'complication',
#   'time',
#   'bullshit',
#   'wouldexpect',
#   'anyone',
#   'close',
#   'respect',
#   'much',
#   'things',
#   'outside',
#   'living',
#   'healthy',
#   'fitlifestyle',
#   'really',
#   'looking_forward',
#   'camping_backpacking',
#   'biking_etc',
#   'also',
#   'really_enjoy',
#   'going',
#   'anice',
#   'meal',
#   'tasty',
#   'cocktails',
#   'beer',
#   'musicnightlife',
#   'thing',
#   'drum',
#   'bass',
#   'time',
#   'time',
#   'vealready',
#   'landed',
#   'gigs',
#   'bay_area',
#   'much',
#   'involvedin',
#   'dnb',
#   'electronic',
#   'genres',
#   'love',
#   'live_music',
#   'asmuch',
#   'basically',
#   'life',
#   'working_hard',
#   'playing',
#   'hard',
#   'made',
#   'lot',
#   'sacrifices',
#   'invested',
#   'much',
#   'effort',
#   'getmyself',
#   'industry',
#   'two',
#   'often',
#   'overlap',
#   'issomething',
#   'fairly',
#   'proud',
#   'learned_lot',
#   'ofcool',
#   'stuff',
#   'far',
#   'plan',
#   'continue',
#   'prettyexcited',
#   'see',
#   'take'],
#  ['favorite_things',
#   'riding_motorcycle',
#   'curvy',
#   'roadscurling',
#   'next',
#   'book',
#   'seriesfinding',
#   'great',
#   'photographsbuilding',
#   'thingsjoking',
#   'around',
#   'friends',
#   'finding',
#   'funny',
#   'momentsthe',
#   'starswindy',
#   'daysliving',
#   'near',
#   'beachlove',
#   'compassionmusiccooking',
#   'dinner',
#   'friendsometimes',
#   'take',
#   'different',
#   'route',
#   'see_itgoes',
#   'photos',
#   'available',
#   'facebook',
#   'peak',
#   'thoseunguarded',
#   'moments'],
#  ['relocated_san',
#   'francisco',
#   'half',
#   'year_ago',
#   'awesomefew',
#   'months',
#   'let',
#   'explore',
#   'diverse',
#   'parts',
#   'city',
#   'finda',
#   'gorgeous',
#   'victorian',
#   'house',
#   'live',
#   'meet',
#   'awesome',
#   'roommateswho',
#   'became',
#   'best',
#   'friends',
#   'find',
#   'first',
#   'american',
#   'emotionalsoul',
#   'mates',
#   'ride',
#   'hot',
#   'european',
#   'wheels',
#   'hilly',
#   'streets',
#   'sanfrancisco',
#   'winding',
#   'road',
#   'stinson_beach',
#   'swim',
#   'thefreezing',
#   'waters',
#   'bay',
#   'walk',
#   'ocean_beach',
#   'full_moon',
#   'onwarm',
#   'starry',
#   'nights',
#   'experience',
#   'great',
#   'outdoors_hiking',
#   'andcross',
#   'country_skiing',
#   'fall',
#   'love',
#   'local',
#   'diversity',
#   'andopenness',
#   'abundance',
#   'cuisine',
#   'embracement',
#   'activelifestyle',
#   'awesome',
#   'city',
#   'live',
#   'one',
#   'canloose',
#   'continuous',
#   'chase',
#   'newelties',
#   'adventure',
#   'people',
#   'around',
#   'support',
#   'amazing',
#   'run',
#   'fornew',
#   'experiences',
#   'absorbing',
#   'atmosphere',
#   'pastsix',
#   'months',
#   'finally',
#   'revelling',
#   'clamness',
#   'findinside',
#   'like',
#   'maybe',
#   'many',
#   'bright',
#   'peoplehere',
#   'come',
#   'embrace',
#   'city',
#   'home',
#   'beginning',
#   'tostabilize',
#   'live',
#   'well',
#   'paced',
#   'life',
#   'time',
#   'personal',
#   'andprofessional',
#   'growth',
#   'fun',
#   'close_friends',
#   'sports',
#   'keep',
#   'thebalance',
#   'body_mind',
#   'time',
#   'ponder',
#   'andreflect',
#   'way',
#   'life'],
#  ['tend',
#   'think',
#   'way',
#   'comedian',
#   'nearlyeverything',
#   'laugh',
#   'particular',
#   'activity',
#   'adventures',
#   'key',
#   'ingredient',
#   'happiness',
#   'whether',
#   'anew',
#   'restaurant',
#   'hike',
#   'sport',
#   'usually',
#   'forging',
#   'ahead',
#   'towardsomething',
#   'new',
#   'coming'],
#  ['completely',
#   'fake',
#   'summary',
#   'wrote',
#   'feeling',
#   'coy',
#   'like',
#   'nature',
#   'know',
#   'like',
#   'plants',
#   'sticks',
#   'stuff',
#   'like',
#   'ilike',
#   'girl',
#   'special',
#   'things',
#   'like',
#   'might',
#   'wear',
#   'ado',
#   'rag',
#   'maybe',
#   'spray',
#   'paint',
#   'car',
#   'little',
#   'things',
#   'reallycrushin',
#   'girl',
#   'light',
#   'incense',
#   'put',
#   'fancy',
#   'robe',
#   'sing',
#   'kid',
#   'rock',
#   'songs',
#   'cook',
#   'hamburgerhelper',
#   'real',
#   'bit',
#   'clumsy',
#   'expert',
#   'silly',
#   'dancing',
#   'grew',
#   'ina',
#   'ghost',
#   'town',
#   'like',
#   'living',
#   'simply',
#   'enjoy',
#   'subtlety',
#   'creativity',
#   'nostalgia',
#   'quaint',
#   'old_fashioned',
#   'things',
#   'makemistakes',
#   'always',
#   'try',
#   'right',
#   'thing',
#   'richman',
#   'got',
#   'heart_gold',
#   'honest',
#   'good_natured',
#   'bee',
#   'knees'],
#  ['bay_area',
#   'transplant',
#   'six_years',
#   'straight',
#   'outta',
#   'tennessee',
#   'play',
#   'sum',
#   'musick',
#   'make',
#   'sum',
#   'things',
#   'goes',
#   'shows',
#   'preferspersonal',
#   'interaction',
#   'social_interaction',
#   'like',
#   'outalot',
#   'everybody',
#   'shuld',
#   'stop_smell',
#   'roses',
#   'timeand',
#   'lets_see',
#   'wuld',
#   'happen',
#   'swear',
#   'really',
#   'abad',
#   'speller',
#   'unique',
#   'method',
#   'typing',
#   'acar',
#   'really',
#   'good',
#   'driver',
#   'think',
#   'generally',
#   'prettypleasant',
#   'person',
#   'hang',
#   'dunno',
#   'tell',
#   'like',
#   'toride',
#   'bike',
#   'really',
#   'slowly',
#   'helmet',
#   'people',
#   'think',
#   'ilook',
#   'like',
#   'weezer',
#   'guess',
#   'really',
#   'see',
#   'theresemblance'],
#  ['hey',
#   'hope',
#   'well',
#   'great',
#   'summer',
#   'vebeen',
#   'denver',
#   'back',
#   'till',
#   '12th',
#   'talk',
#   'youthen',
#   'currently',
#   'work',
#   'graphic_designer',
#   'focused',
#   'marketing',
#   'andadvertising',
#   'graduated_university',
#   'colorado',
#   'boulderclass',
#   'humble',
#   'energetic',
#   'willing',
#   'optimistic',
#   'honestand',
#   'lot',
#   'gratitude',
#   'live',
#   'today',
#   'moment',
#   'andthat',
#   'important',
#   'believe',
#   'succcess',
#   'without',
#   'stepping',
#   'ontoes',
#   'positive',
#   'strive_best',
#   'positivityand',
#   'humor',
#   'key',
#   'laughter',
#   'specialty',
#   'looking_meet',
#   'new',
#   'friends',
#   'possibly',
#   'something',
#   'ihave',
#   'expectations',
#   'keep',
#   'eyes',
#   'open',
#   'special',
#   'girlto',
#   'see_goes',
#   'consider',
#   'gentleman',
#   'child',
#   'heart',
#   'alot',
#   'energy',
#   'mean',
#   'immature',
#   'way',
#   'lot',
#   'funand',
#   'anything',
#   'raised',
#   'good',
#   'family',
#   'beenlucky',
#   'enough',
#   'travel',
#   'around_world',
#   'plan',
#   'keeping',
#   'thatup',
#   'enjoy',
#   'japanese_culture',
#   'oahu',
#   'beautiful',
#   'oceans',
#   'north',
#   'shore',
#   'waimea',
#   'bay',
#   'pipeline',
#   'kailua',
#   'makapu',
#   'sandy',
#   'music',
#   'mydog',
#   'side',
#   'staying',
#   'watching_movies',
#   'dating',
#   'sweethearts',
#   'ipad',
#   'iphone',
#   'dining',
#   'traveling',
#   'snowboarding',
#   'fly_fishing',
#   'camping',
#   'watching',
#   'pro_sports',
#   'aimlessly',
#   'running',
#   'around_city',
#   'watching_movies',
#   'bed',
#   'taking',
#   'driving',
#   'range',
#   'surfingwith',
#   'older_brother',
#   'cycling',
#   'going_shows',
#   'city',
#   'andgoing',
#   'friends'],
#  ['full_time',
#   'student',
#   'full_time',
#   'square',
#   'change',
#   'year',
#   'year',
#   'used',
#   'love',
#   'computer_games',
#   'drinking',
#   'finding',
#   'hatethem',
#   'time',
#   'passes',
#   'get_wrong',
#   'still',
#   'enjoy',
#   'nightout',
#   'every_month',
#   'lazy',
#   'saturday',
#   'computer',
#   'andagain',
#   'obsession',
#   'moment',
#   'include',
#   'long_drives',
#   'nightafter',
#   'work',
#   'hitting_gym',
#   'weekends',
#   'like',
#   'sit',
#   'andhome',
#   'prepare',
#   'week',
#   'ahead'],
#  ['lost', 'needle', 'haystack', 'found', 'prettymuch', 'sums'],
#  ['love',
#   'life',
#   'okcupid',
#   'telling',
#   'three_words',
#   'enough',
#   'okthen',
#   'moved_bay',
#   'area',
#   'february',
#   'know',
#   'anyone',
#   'chance',
#   'pretend',
#   'coolest',
#   'kid',
#   'townand',
#   'know',
#   'better',
#   'believe',
#   'still',
#   'enough',
#   'fine',
#   'detailed',
#   'description',
#   'born',
#   'lead',
#   'armies',
#   'darkness',
#   'ruinous',
#   'victory',
#   'gifted',
#   'witha',
#   'vast',
#   'range',
#   'abilities',
#   'achieving',
#   'destiny',
#   'cursed',
#   'theforces',
#   'good',
#   'crippled',
#   'ethics',
#   'honesty',
#   'compassion',
#   'usual',
#   'story',
#   'good',
#   'triumphs',
#   'evil',
#   'foiled',
#   'blah',
#   'blahblah',
#   'read_write',
#   'name',
#   'job',
#   'home',
#   'carand',
#   'teeth',
#   'use',
#   'oscilloscope',
#   'showermyself',
#   'also',
#   'know',
#   'people',
#   'recently',
#   'published',
#   'loathsome',
#   'people',
#   'usa',
#   'list',
#   'single',
#   'one',
#   'ofthem',
#   'mom',
#   'delighted',
#   'hear',
#   'though',
#   'youmay',
#   'feel',
#   'little_bit',
#   'insulted',
#   'poorly',
#   'hidden',
#   'relief'],
#  ['grew',
#   'new_york',
#   'san_diego',
#   'half',
#   'half',
#   'root',
#   'theknicks',
#   'mets',
#   'jets',
#   'around',
#   'cheat',
#   'thepadres',
#   'chargers',
#   'prefer',
#   'happy_hour',
#   'last',
#   'call',
#   'use',
#   'sound',
#   'effects',
#   'story',
#   'telli'],
#  ['really',
#   'like',
#   'summarizing',
#   'right',
#   'seemslike',
#   'every',
#   'time',
#   'try',
#   'come',
#   'pile',
#   'ofcontradictions',
#   'shy',
#   'extroverti',
#   'grounded',
#   'dreameri',
#   'lazy',
#   'adventureri',
#   'open_minded',
#   'sometimes',
#   'stubborni',
#   'city',
#   'person',
#   'mountain',
#   'mani',
#   'competitive',
#   'try_avoid',
#   'competitioni',
#   'social',
#   'bit',
#   'misanthropici',
#   'generally',
#   'meticulous',
#   'often',
#   'sort',
#   'carelessi',
#   'strong_sense',
#   'self',
#   'social',
#   'chameleoni',
#   'complete',
#   'confidence',
#   'succeed',
#   'whatever',
#   'yet',
#   'often',
#   'terrified',
#   'failure',
#   'letting',
#   'others',
#   'lot',
#   'best',
#   'friends',
#   'like',
#   'first',
#   'metme',
#   'took',
#   'time',
#   'get_know',
#   'figured',
#   'thati',
#   'actually',
#   'caring',
#   'entertaining',
#   'giving',
#   'honest_loyal',
#   'patient',
#   'playful',
#   'open',
#   'stimulating',
#   'companion',
#   'course',
#   'otherslove',
#   'first_sight',
#   'never_stop',
#   'maybe',
#   'seefor',
#   'clever',
#   'creative',
#   'complicated'],
#  ['free', 'culture', 'nerd', 'travel', 'talk', 'teach'],
#  ['originally',
#   'france_lived',
#   'different_countries',
#   'moved',
#   'here3',
#   'years_ago',
#   'totally',
#   'fell_love',
#   'bay_area',
#   'justlooking',
#   'meet_new',
#   'people',
#   'hangout',
#   'explore',
#   'area',
#   'ilove_travel',
#   'fact',
#   'got_back',
#   'central_america',
#   'wherei',
#   'spent',
#   'month',
#   'short',
#   'also',
#   'love_outdoors',
#   'going_adventures',
#   'rock_climbing',
#   'snowboarding_hiking',
#   'kayaking',
#   'name',
#   'also',
#   'started',
#   'keep',
#   'bees',
#   'backyard',
#   'really',
#   'afascinating',
#   'hobby',
#   'get',
#   'delicious',
#   'local',
#   'honey'],
#  ['grew',
#   'iowa',
#   'gets',
#   'bad',
#   'rap',
#   'let',
#   'first',
#   'totell',
#   'youiowa',
#   'way',
#   'cooler',
#   'think',
#   'iowa',
#   'iwent_school',
#   'pittsburgh',
#   'spending',
#   'summer',
#   'sanfrancisco',
#   'living',
#   'soma',
#   'know',
#   'guy',
#   'always',
#   'researching',
#   'analyzing',
#   'know',
#   'friend',
#   'working_project',
#   'send',
#   'relevantideas',
#   'articles',
#   'come_across',
#   'however',
#   'intellectual',
#   'prowessdoesn',
#   'permeate',
#   'aspects_life',
#   'friends',
#   'make',
#   'fun',
#   'ofme',
#   'absent_minded',
#   'professor',
#   'type',
#   'give',
#   'hard',
#   'problemand',
#   'excel',
#   'moving',
#   'apartment',
#   'might',
#   'well',
#   'berocket',
#   'science',
#   'eek',
#   'always',
#   'room',
#   'improvement',
#   'love',
#   'sound',
#   'plane',
#   'tires',
#   'touching',
#   'country',
#   'venever',
#   'visited',
#   'japan',
#   'next_list',
#   'though',
#   'visit',
#   'germanyor',
#   'london',
#   'heartbeat',
#   'intuitive',
#   'side',
#   'life',
#   'recently',
#   'beenenthusiastically',
#   'exploring',
#   'buddhism',
#   'meditation',
#   'payingattention',
#   'spaces',
#   'things',
#   'learn',
#   'theless',
#   'know',
#   'refreshing',
#   'awash',
#   'mystery',
#   'theuniverse',
#   'style',
#   'important',
#   'expression',
#   'clothingbut',
#   'draw_line',
#   'pajamas',
#   'outerwear',
#   'get',
#   'recomfortable',
#   'know',
#   'saying'],
#  ['straight',
#   'point',
#   'sugar',
#   'coat',
#   'mean',
#   'well',
#   'sarcastic',
#   'anda',
#   'clown',
#   'good',
#   'friend',
#   'talk',
#   'clumsy',
#   'yeah',
#   'fall',
#   'overmyself',
#   'kid_heart',
#   'still',
#   'dreamin',
#   'big_dreams',
#   'bad',
#   'withnames',
#   'known',
#   'get',
#   'spot',
#   'white',
#   'shirt',
#   'inevitable',
#   'ilike',
#   'iron',
#   'clothes',
#   'relaxing',
#   'running',
#   'gets',
#   'theendorphins',
#   'going',
#   'convinced',
#   'matching',
#   'online_thing',
#   'yet_still',
#   'anything',
#   'spossible',
#   'still_reading',
#   'maybe',
#   'still',
#   'interested',
#   'curious',
#   'hey',
#   'looking',
#   'perfect',
#   'exist',
#   'thewhole',
#   'maybe',
#   'different',
#   'maybe',
#   'lots',
#   'imperfections',
#   'butmaybe',
#   'perfect',
#   'know'],
#  ['really',
#   'like',
#   'meeting_new',
#   'people',
#   'small',
#   'world',
#   'networks',
#   'fascinateme',
#   'beer',
#   'important',
#   'without',
#   'beer',
#   'would',
#   'nocivilization',
#   'somehow',
#   'sing',
#   'spanish',
#   'speak',
#   'suppose',
#   'musicis',
#   'universal',
#   'language',
#   'coffee',
#   'enthusiast',
#   'one',
#   'singing',
#   'riding_bike',
#   'around',
#   'themission'],
#  ['way',
#   'boring',
#   'reveal',
#   'plaintext',
#   'guess',
#   'interesting',
#   'discover',
#   'eachother',
#   'person',
#   'plus',
#   'wary',
#   'online',
#   'profiles'],
#  ['adventurer',
#   'first',
#   'take',
#   'calculatedrisks',
#   'whenever',
#   'seems',
#   'fun',
#   'always',
#   'take_care',
#   'aroundme',
#   'writer',
#   'astory',
#   'teller',
#   'photographer',
#   'things',
#   'arebasically',
#   'thing',
#   'love',
#   'playing',
#   'lights',
#   'sound',
#   'really',
#   'machine',
#   'locomotion',
#   'pretty',
#   'blinky',
#   'thingson',
#   'love',
#   'driving',
#   'racing',
#   'flying',
#   'sailing',
#   'sky_diving',
#   'adrenaline',
#   'issacred',
#   'said',
#   'appreciate',
#   'night',
#   'home',
#   'goodbook',
#   'bottle_wine',
#   'company',
#   'movie',
#   'andconversation',
#   'time',
#   'though',
#   'like',
#   'hear',
#   'themovie',
#   'focus',
#   'later'],
#  ['extroverted',
#   'charming',
#   'yet',
#   'enjoy',
#   'living',
#   'alone',
#   'mysanctuary',
#   'apartment',
#   'strong',
#   'dominant',
#   'personalitythat',
#   'tempered',
#   'deep',
#   'stable',
#   'emotions',
#   'comfortable',
#   'withmyself',
#   'flaws',
#   'trying',
#   'work',
#   'selfbetterment',
#   'looking',
#   'unique',
#   'woman',
#   'modest',
#   'herbeauty',
#   'values',
#   'healthy_active',
#   'lifestyle',
#   'independentbut',
#   'willing',
#   'open',
#   'little',
#   'dependence'],
#  ['raised',
#   'sailor',
#   'taxidermist',
#   'pacific',
#   'norhtwest',
#   'imno',
#   'stranger',
#   'cursing',
#   'whiskey',
#   'swilling',
#   'plainstrange',
#   'ahead',
#   'try',
#   'weirdest',
#   'professional',
#   'student',
#   'life',
#   'pretty',
#   'good',
#   'details',
#   'boring',
#   'get',
#   'fancy',
#   'degree',
#   'one',
#   'ofthese',
#   'days',
#   'importantly',
#   'cat',
#   'allergy',
#   'sorry',
#   'cat',
#   'ladies',
#   'makeme',
#   'sneeze'],
#  ['originally_southern',
#   'california',
#   'moved_san',
#   'fransico',
#   'topursue',
#   'degree',
#   'film',
#   'love',
#   'movies',
#   'working',
#   'film',
#   'relatedprojects',
#   'like',
#   'exercising',
#   'staying_active',
#   'looking_someoneto',
#   'hang'],
#  ['moved',
#   'months_ago',
#   'far',
#   'really',
#   'liking',
#   'buti',
#   'looking',
#   'grow',
#   'circle_friends',
#   'hitting',
#   'acute',
#   'girl',
#   'along_way',
#   'even_better',
#   'latest',
#   'interest',
#   'rock_climbing',
#   'going',
#   'week',
#   'toplanet',
#   'granite',
#   'blast',
#   'perhaps',
#   'good',
#   'way',
#   'meet',
#   'ifyou',
#   'als',
#   'climb',
#   'belay',
#   'partners',
#   'originally_chicago',
#   'area',
#   'still',
#   'verysmall',
#   'family',
#   'lives',
#   'last_years',
#   'enjoying',
#   'beaches_mountains',
#   'deserts',
#   'san_diego',
#   'adventurer',
#   'heart',
#   'always',
#   'seeking',
#   'something',
#   'theordinary',
#   'challenge',
#   'spark',
#   'imagination',
#   'simplysurprise',
#   'least',
#   'expecting',
#   'ideal_girl',
#   'would',
#   'thesame',
#   'traveled',
#   'many_places',
#   'world',
#   'still',
#   'tonleft',
#   'see',
#   'major',
#   'goal',
#   'find',
#   'girl',
#   'sharesthis',
#   'travel_bug',
#   'point',
#   'next',
#   'years',
#   'dlove',
#   'quit_job',
#   'travel',
#   '1yr',
#   'girl',
#   'love',
#   'thenreturn',
#   'normal',
#   'life',
#   'career',
#   'lives',
#   'enriched'],
#  ['like',
#   'everyone_else',
#   'site',
#   'feel',
#   'awkward',
#   'trying',
#   'summyself',
#   'box',
#   'sake',
#   'strangers',
#   'internet',
#   'nowthat',
#   'got',
#   'wayi',
#   'born',
#   'calgary',
#   'spent_childhood',
#   'around',
#   'area',
#   'came',
#   'sunny_california',
#   'school',
#   'funny',
#   'loyal',
#   'patient',
#   'cynical',
#   'laid_back',
#   'dreamer',
#   'something',
#   'hopelessromantic',
#   'big_believer',
#   'finding',
#   'humor',
#   'everyday',
#   'lifeand',
#   'compulsively',
#   'crack',
#   'wise',
#   'ridiculous',
#   'things',
#   'see',
#   'inadvertisements',
#   'politics',
#   'restaurant',
#   'menus',
#   'etc',
#   'alsosquirrels',
#   'squirrels',
#   'get',
#   'funny',
#   'shit',
#   'love',
#   'read',
#   'andcan',
#   'easily',
#   'spend_hours',
#   'good',
#   'bookstore',
#   'huge',
#   'cinephileand',
#   'right',
#   'mood',
#   'enjoy',
#   'bad',
#   'movie',
#   'every',
#   'bit',
#   'much',
#   'agood',
#   'one',
#   'see',
#   'aforementioned',
#   'enjoyment',
#   'ridiculous',
#   'afan',
#   'hugs',
#   'backrubs',
#   'giving',
#   'getting',
#   'strongly',
#   'supportwomen',
#   'rights',
#   'gay_rights',
#   'forms',
#   'socialequality',
#   'might',
#   'get_along',
#   'well',
#   'justsayin',
#   'love',
#   'music',
#   'also',
#   'appreciate',
#   'good',
#   'stretch',
#   'ofsilence',
#   'every',
#   'love',
#   'collecting',
#   'information',
#   'howthings_work',
#   'happily',
#   'geek',
#   'obscure',
#   'facet',
#   'ofbiology',
#   'physics',
#   'psychology',
#   'history',
#   'anthropology',
#   'enjoy_theoutdoors',
#   'even_though',
#   'get',
#   'often',
#   'like',
#   'especially',
#   'foresty',
#   'areas',
#   'something',
#   'comforting',
#   'trees',
#   'believe',
#   'astrology',
#   'means',
#   'explanation',
#   'forwhy',
#   'almost_everything',
#   'read',
#   'scorpios',
#   'matches',
#   'dead'],
#  ['mmmmmm', 'idk', 'say', 'ask'],
#  ['still',
#   'new',
#   'moved_chicago',
#   'last_august',
#   'wasborn',
#   'philippines',
#   'first',
#   'moved',
#   'almost3',
#   'lead',
#   'pretty',
#   'remarkable',
#   'life',
#   'earned',
#   'lot',
#   'awesomeopportunities',
#   'taken',
#   'advantage',
#   'moving_around',
#   'thecountry',
#   'since',
#   'family',
#   'moved',
#   'helped',
#   'learn',
#   'seek',
#   'outopportunities',
#   'taught',
#   'able',
#   'put_outthere',
#   'like',
#   'park',
#   'read',
#   'love_travel',
#   'anoutdoors',
#   'person',
#   'like',
#   'bouldering',
#   'water',
#   'thefrigid',
#   'ocean',
#   'though',
#   'snowboarding',
#   'soccer',
#   'hiking',
#   'bike_riding',
#   'andjust',
#   'touring',
#   'city'],
#  ['names',
#   'josh',
#   'create',
#   'art',
#   'living',
#   'work',
#   'aconceptual',
#   'artist',
#   'north_beach',
#   'studio',
#   'spare_time',
#   'liketo',
#   'play',
#   'music',
#   'adventure',
#   'around_city',
#   'check',
#   'music',
#   'justhang',
#   'home',
#   'prefer',
#   'meeting_people',
#   'real',
#   'life',
#   'notopposed',
#   'meeting_new',
#   'friends',
#   'internets',
#   'hit',
#   'like',
#   'know'],
#  ['new',
#   'boston',
#   'thought',
#   'might',
#   'good',
#   'way',
#   'tomeet_new',
#   'people',
#   'instead',
#   'writing',
#   'think',
#   'would',
#   'better',
#   'toldyou',
#   'looking',
#   'always',
#   'meet_new',
#   'friends',
#   'know',
#   'want',
#   'agirl',
#   'want',
#   'waste_time',
#   'enjoy',
#   'ordering',
#   'something',
#   'different',
#   'everytime',
#   'arestaurant',
#   'speaking',
#   'restaurants',
#   'offering',
#   'split',
#   'thecheck',
#   'first_date',
#   'tells',
#   'lot',
#   'person',
#   'thansomeone',
#   'assumes',
#   'taken_care',
#   'even_though',
#   'never',
#   'letyou',
#   'tall',
#   'like',
#   'tall',
#   'girls',
#   'sexy',
#   'sweetzone',
#   'ski_snowboard',
#   'know',
#   'state',
#   'jackson',
#   'hole',
#   'inyou',
#   'pretty_much',
#   'beat',
#   'everyone',
#   'date',
#   'non',
#   'skier',
#   'texpect',
#   'hang',
#   'powder',
#   'day',
#   'adventures',
#   'fun',
#   'lazy',
#   'like',
#   'new_things',
#   'time',
#   'mother',
#   'taught',
#   'cook',
#   'great',
#   'atsome',
#   'point',
#   'make',
#   'cook',
#   'know',
#   'itsnot',
#   'try',
#   'pepper',
#   'best',
#   'soda',
#   'hate',
#   'tappreciate',
#   'owning',
#   'gym',
#   'membership',
#   'good',
#   'thing',
#   'hiding',
#   'secret',
#   'talents',
#   'amazing',
#   'things',
#   'want',
#   'tosee',
#   'people',
#   'use',
#   'number',
#   'instead',
#   'stupid',
#   'importantly',
#   'dateable',
#   'sleep',
#   'withsomeone',
#   'first',
#   'night'],
#  ['like',
#   'horses',
#   'horses',
#   'understanding',
#   'ladieslove',
#   'horses',
#   'always',
#   'horse',
#   'ing',
#   'around',
#   'please',
#   'sing',
#   'hey',
#   'soul',
#   'sister',
#   'like',
#   'hay',
#   'getit',
#   'sing',
#   'hey',
#   'soul',
#   'sister',
#   'pulling',
#   'train',
#   'ido',
#   'want',
#   'train',
#   'pulled',
#   'witty',
#   'may',
#   'travel',
#   'list_places',
#   'vevisi',
#   'last_years',
#   'big_sur',
#   'death_valley',
#   'guilin',
#   'guyana',
#   'hollister',
#   'hong_kong',
#   'horseheaven',
#   'hills',
#   'iceland',
#   'king',
#   'canyon',
#   'las_vegas',
#   'lassen',
#   'macau',
#   'mexico_city',
#   'mono',
#   'lake',
#   'oaxaca',
#   'nova',
#   'scotia',
#   'red',
#   'mountain',
#   'sequoia',
#   'trinidad',
#   'yosemite',
#   'mom',
#   'houseam',
#   'dead',
#   'pan',
#   'questing',
#   'mark',
#   'indecisive',
#   'indincisive'],
#  ['mein',
#   'nutshell',
#   'easy_going',
#   'earth',
#   'kind_guy',
#   'whoappreciates',
#   'life',
#   'great',
#   'things',
#   'offer',
#   'afterall',
#   'purpose',
#   'life',
#   'make',
#   'lasting',
#   'memories',
#   'workhard_play',
#   'hard',
#   'soft_spot',
#   'outdoors',
#   'avidhiker',
#   'camper',
#   'beach',
#   'relaxer',
#   'always',
#   'open',
#   'trying_newthings',
#   'friends',
#   'soon',
#   'friends'],
#  ['friend',
#   'suggested',
#   'try',
#   'online_thing',
#   'see',
#   'whatit',
#   'like',
#   'let_know',
#   'feel',
#   'totally',
#   'weird',
#   'andit',
#   'even',
#   'feels',
#   'bit',
#   'creepy',
#   'hell',
#   'right',
#   'goes',
#   'grew',
#   'humble',
#   'country_boy',
#   'rolling',
#   'fields',
#   'centralmassachusetts',
#   'riding_bike',
#   'playing',
#   'woods',
#   'went',
#   'umass',
#   'amherst',
#   'moved',
#   'boston',
#   'waslandscape',
#   'architect',
#   'park',
#   'planner',
#   'national',
#   'parkservice',
#   'left',
#   'dream_job',
#   'become',
#   'full_time',
#   'musician',
#   'drums',
#   'andbandleader',
#   'years',
#   'left',
#   'dream_job',
#   'move',
#   'got',
#   'teaching_credential',
#   'atuniversity',
#   'san_francisco',
#   'wrapping',
#   'mastersthere',
#   'currently',
#   'teaching',
#   'high_school',
#   'science',
#   'public',
#   'charter',
#   'herein_san',
#   'francisco',
#   'loving',
#   'another',
#   'dream_job',
#   'within',
#   'years',
#   'innumerable',
#   'adventures',
#   'countless',
#   'friends',
#   'lost',
#   'loves',
#   'hit',
#   'misses',
#   'many',
#   'proverbial',
#   'roller',
#   'coasterrides',
#   'tell',
#   'ever_meet'],
#  ['temporary',
#   'hiatus',
#   'trying',
#   'define',
#   'particularly',
#   'concise',
#   'blurbs',
#   'however',
#   'finding',
#   'thisreluctance',
#   'summarize',
#   'might',
#   'adversely',
#   'affecting',
#   'mysocio',
#   'economic',
#   'success',
#   'levels',
#   'found',
#   'blurb',
#   'wordy',
#   'confusing',
#   'wholly',
#   'devoid',
#   'humor',
#   'irony',
#   'likely',
#   'find',
#   'meannoying'],
#  ['sean',
#   'sites',
#   'always',
#   'wired',
#   'experience',
#   'obviously',
#   'free',
#   'well',
#   'meetpeople',
#   'feel_free',
#   'shoot_message',
#   'want',
#   'thats',
#   'whywere',
#   'right',
#   'still',
#   'going',
#   'school',
#   'workingas',
#   'medic',
#   'right',
#   'lots',
#   'crazy',
#   'story',
#   'wana',
#   'hearthem',
#   'eather',
#   'going',
#   'straight',
#   'med_school',
#   'intobusiness',
#   'take',
#   'fathers',
#   'business',
#   'well',
#   'see_happens',
#   'hope_hear',
#   'soon'],
#  ['business_owner',
#   'backend',
#   'frontend',
#   'developer',
#   'frequent',
#   'hiker',
#   'apodcast',
#   'listener',
#   'trying',
#   'banjo',
#   'player',
#   'former',
#   'bass',
#   'player',
#   'former',
#   'inorganic',
#   'chemist',
#   'former',
#   'theoretical',
#   'magneticresonator',
#   'realized',
#   'staring',
#   'lava',
#   'feet',
#   'away',
#   'havingit',
#   'toss',
#   'bits',
#   'molten',
#   'rock',
#   'probably',
#   'single',
#   'greatestthing',
#   'world',
#   'gonna',
#   'hear',
#   'lady',
#   'help',
#   'raised_southern',
#   'style',
#   'southern',
#   'cali',
#   'accentonly',
#   'comes',
#   'provoked',
#   'similar',
#   'company',
#   'beverageinduced',
#   'aikidoist',
#   'hip_hop',
#   'banjo',
#   'lover',
#   'waiting',
#   'thatgenre',
#   'created',
#   'former',
#   'chemist',
#   'turned',
#   'business_owner',
#   'frequent',
#   'traveler',
#   'itgets',
#   'boring',
#   'sitting',
#   'one',
#   'spot',
#   'long',
#   'really',
#   'liketo',
#   'new',
#   'spot',
#   'sit',
#   'drive_fast',
#   'expect',
#   'people',
#   'better',
#   'drivers',
#   'theyare',
#   'shall',
#   'let',
#   'known',
#   'really',
#   'open',
#   'ness',
#   'crap',
#   'may',
#   'ask',
#   'answer',
#   'oakland',
#   'bag',
#   'tried',
#   'like',
#   'even',
#   'like',
#   'dealing',
#   'withmore',
#   'one',
#   'conversation',
#   'time',
#   'could',
#   'atime',
#   'thing',
#   'intj',
#   'unite',
#   'right',
#   'heard',
#   'matters',
#   'anything',
#   'according',
#   'two',
#   'signs',
#   'aries',
#   'dragon',
#   'psych',
#   'profile',
#   'intj',
#   'anintroverted',
#   'good',
#   'money',
#   'loyal',
#   'slightly',
#   'competitive',
#   'overgeneralizing',
#   'asshole',
#   'uncanny',
#   'ability',
#   'focus',
#   'mostlytrue',
#   'basically',
#   'lookin',
#   'partner_crime',
#   'really',
#   'likegames',
#   'tend',
#   'lose',
#   'lot',
#   'prefer',
#   'play',
#   'themanymore',
#   'like',
#   'side',
#   'iget',
#   'sheesh',
#   'questions',
#   'madquestion',
#   'website',
#   'right',
#   'gummy',
#   'worms',
#   'gummy',
#   'bears',
#   'red',
#   'blue_green',
#   'say',
#   'yellow',
#   'orange',
#   'brown',
#   'disqualified',
#   'bla',
#   'fleck',
#   'tony',
#   'trischka',
#   'brooklyn',
#   'trees',
#   'snow',
#   'sand'],
#  ['almost', 'decided', 'want', 'igrow'],
#  ['graduated_berkeley',
#   'degree',
#   'eecs',
#   'electricalengineering',
#   'computer_science',
#   'enjoy',
#   'things',
#   'withcomputer',
#   'cars',
#   'two',
#   'main',
#   'hobbies',
#   'immigrated',
#   'settled',
#   'losangeles',
#   'amusing',
#   'funny',
#   'geeky'],
#  ['single',
#   'girls',
#   'come',
#   'get',
#   'hahahai',
#   'tall',
#   'white',
#   'guy',
#   'looking',
#   'younger',
#   'woman',
#   'ask_meanything',
#   'would_like',
#   'know'],
#  ['ill',
#   'matic',
#   'drastically',
#   'fantastic',
#   'orgasmic',
#   'incomparable',
#   'plastic',
#   'seen',
#   'drastic',
#   'spastic',
#   'yet',
#   'prophetic',
#   'facts',
#   'areprophylactic'],
#  ['sorry',
#   'lack',
#   'detailed',
#   'pictures',
#   'lot',
#   'friends',
#   'andcolleagues',
#   'visit',
#   'site',
#   'pretty_sure',
#   'wouldrecognize'],
#  ['upon',
#   'viewing',
#   'big',
#   'empty',
#   'box',
#   'big',
#   'case',
#   'stage',
#   'fright',
#   'kinda',
#   'like',
#   'pushed',
#   'stage',
#   'front',
#   'mike',
#   'andsomeone',
#   'turned',
#   'big',
#   'spotlight',
#   'tap',
#   'tap',
#   'thing',
#   'yep',
#   'start',
#   'could',
#   'add',
#   'fourth',
#   'adjective',
#   'would',
#   'optimistic',
#   'theglass',
#   'always',
#   'half_full',
#   'enough',
#   'share',
#   'far',
#   'pollyannic',
#   'rational',
#   'funny',
#   'shy'],
#  ['part',
#   'geek',
#   'part',
#   'silly',
#   'part',
#   'ridiculous',
#   'guy',
#   'always',
#   'open',
#   'tomeeting',
#   'new_people',
#   'seeing',
#   'click',
#   'geek',
#   'always',
#   'game',
#   'intellectually',
#   'stimulatingconversation',
#   'consider',
#   'sapiosexual',
#   'thesame',
#   'certainly',
#   'get_along',
#   'definitely',
#   'somewhat',
#   'silly',
#   'guilty',
#   'personmaking',
#   'ridiculous',
#   'expressions',
#   'pictures',
#   'desperatelytry',
#   'scrub',
#   'facebook',
#   'ridiculous',
#   'part',
#   'like',
#   'try',
#   'completely',
#   'new',
#   'thingsnot',
#   'comfort_zone',
#   'bonus_points',
#   'triggers',
#   'adrenalinejunkie',
#   'would',
#   'love',
#   'try',
#   'something_new',
#   'somethingin',
#   'mind',
#   'furthermore',
#   'engineer_profession',
#   'spent_childhood',
#   'tinkering',
#   'andbreaking',
#   'things',
#   'somehow',
#   'turned',
#   'career',
#   'bay_area',
#   'product',
#   'grew',
#   'san_jose',
#   'went_school',
#   'inberkeley',
#   'bears',
#   'san_francisco',
#   'somewhere',
#   'entp',
#   'intp',
#   'hardcore',
#   'car',
#   'person',
#   'average_guy',
#   'drivesaggressively',
#   'someone',
#   'spends',
#   'many',
#   'weekends',
#   'racetrack',
#   'secretly',
#   'dream',
#   'one_day',
#   'professionally',
#   'hobbies',
#   'picked',
#   'photography',
#   'cycling',
#   'foodie',
#   'ing',
#   'fashion',
#   'becoming',
#   'quite',
#   'yuppie',
#   'decently',
#   'athletic',
#   'though',
#   'slightly',
#   'slower',
#   'used',
#   'atswimming',
#   'argh',
#   'optimistic',
#   'competitive',
#   'stubborn'],
#  ['although',
#   'live',
#   'yet',
#   'moving',
#   'since',
#   'know',
#   'two',
#   'people',
#   'city',
#   'would',
#   'cool',
#   'tomeet_new',
#   'people',
#   'good',
#   'describing',
#   'like',
#   'anything',
#   'fun',
#   'going',
#   'outto',
#   'shows',
#   'bars_restaurants',
#   'traveling',
#   'far_away',
#   'countries',
#   'gettinginto',
#   'squirt',
#   'gun',
#   'fights',
#   'strangers',
#   'usual',
#   'know',
#   'beernerd',
#   'computer_geek',
#   'describe'],
#  ['hmmmm',
#   'impossible',
#   'describe',
#   'least',
#   'wiithoutsounding',
#   'like',
#   'applying',
#   'job',
#   'mathy',
#   'nerdy',
#   'guy_enjoys',
#   'figuring_things',
#   'enjoyinghimself',
#   'also',
#   'making',
#   'innuendos',
#   'also',
#   'enjoys',
#   'humor',
#   'espcially',
#   'internet',
#   'humor',
#   'theorizing',
#   'abouttime',
#   'travel',
#   'high_school',
#   'came',
#   'proof',
#   'icould',
#   'define',
#   'whatever',
#   'wanted',
#   'true',
#   'based',
#   'around',
#   'time',
#   'travel',
#   'somehow',
#   'friends',
#   'quite',
#   'convinced',
#   'things',
#   'like',
#   'thinking',
#   'things',
#   'likefiguring',
#   'universe',
#   'way',
#   'society',
#   'howit',
#   'politics',
#   'sucks',
#   'much',
#   'plural',
#   'lookingwords',
#   'actually',
#   'singular',
#   'also',
#   'figuring',
#   'use',
#   'thevarious',
#   'contraptions',
#   'gym',
#   'started',
#   'using',
#   'thati',
#   'actually',
#   'time',
#   'energy',
#   'college',
#   'really',
#   'intense',
#   'awesome',
#   'intense'],
#  ['charmingly',
#   'eccentric',
#   'borderline',
#   'pretentious',
#   'infectiouslyeasygoing',
#   'dude',
#   'thoroughly',
#   'berkelified',
#   'since',
#   'movinghere',
#   'years_ago',
#   'eat_vegetables',
#   'think',
#   'like',
#   'tolive',
#   'antarcticasomeday',
#   'bit',
#   'lucky',
#   'come',
#   'probably',
#   'lab',
#   'assistant',
#   'pretend',
#   'toappreciate',
#   'art_music',
#   'name',
#   'means',
#   'honors',
#   'god',
#   'anatheist',
#   'like',
#   'yes',
#   'know',
#   'sentences',
#   'choppy',
#   'butit',
#   'fun',
#   'way'],
#  ['good',
#   'guy',
#   'looking',
#   'find_someone',
#   'special',
#   'think',
#   'initial',
#   'meeting',
#   'chemistry_important',
#   'lets',
#   'wine_country',
#   'explore_new',
#   'area',
#   'try',
#   'newrestaurant',
#   'enjoy',
#   'nice_glass',
#   'wine',
#   'together',
#   'email',
#   'weeks',
#   'spark',
#   'uponmeeting',
#   'least',
#   'know',
#   'make',
#   'new',
#   'friendshere',
#   'easy',
#   'fun',
#   'easy_going',
#   'spontaneous',
#   'honest'],
#  ['normal',
#   'people',
#   'one',
#   'know',
#   'verywell',
#   'quick',
#   'bellwether',
#   'youtube_com',
#   'watch',
#   'feature',
#   'player_embedded',
#   'tynabziknr8',
#   'music2hold',
#   'sliding',
#   'linoleum',
#   'stocking',
#   'feet',
#   'contest',
#   'agree',
#   'keep',
#   'going',
#   'neutral',
#   'fine2',
#   'goofy',
#   'like',
#   'get',
#   'exceedingly',
#   'simple',
#   'woefully',
#   'complicated',
#   'large',
#   'vocabulary',
#   'begin',
#   'spell',
#   'building',
#   'organizing',
#   'people',
#   'creating',
#   'supporting',
#   'promoting',
#   'art',
#   'twirling',
#   'mustache',
#   'everyday',
#   'hope',
#   'put_effort',
#   'towards',
#   'type',
#   'highminded',
#   'cat',
#   'know',
#   'results',
#   'vary'],
#  ['moved',
#   'cincinnati',
#   'teaching',
#   'privatehigh',
#   'school',
#   'cincy',
#   'working',
#   'start',
#   'redwoodcity',
#   'pretty_easy',
#   'going',
#   'guy',
#   'enjoy_simple',
#   'pleasures',
#   'inlife',
#   'watching_football',
#   'game',
#   'bills',
#   'drinking_beer',
#   'staying_late',
#   'discussing',
#   'nothing',
#   'particular',
#   'eating',
#   'icecream',
#   'sundae',
#   'warm',
#   'summer',
#   'day',
#   'etc',
#   'like',
#   'think',
#   'opinions',
#   'challenged',
#   'able',
#   'havepolitical',
#   'religious',
#   'discussions',
#   'debates',
#   'important',
#   'said',
#   'also',
#   'crack',
#   'numerous',
#   'bad',
#   'charlie',
#   'sheen',
#   'puns',
#   'know',
#   'man',
#   'enough',
#   'coke',
#   'kill',
#   'two',
#   'half',
#   'men',
#   'banter',
#   'hilarity',
#   'bro',
#   'culture',
#   'rant',
#   'parishilton',
#   'rise',
#   'fame',
#   'signifies',
#   'decline',
#   'westerncivilization',
#   'open_minded',
#   'honest',
#   'self_aware'],
#  ['every',
#   'winter',
#   'work',
#   'bring',
#   'bay_area',
#   'love',
#   'mild',
#   'weatherhere',
#   'mlooking',
#   'one',
#   'hangout',
#   'activity',
#   'date',
#   'enjoygood',
#   'time',
#   'drama',
#   'summer',
#   'may',
#   'working',
#   'today',
#   'email',
#   'tex',
#   'phone',
#   'make',
#   'contact',
#   'real',
#   'time',
#   'tokeep',
#   'touch'],
#  ['note',
#   'side',
#   'world',
#   'coupleweeks',
#   '_______________well',
#   'seems',
#   'years',
#   'back',
#   'single',
#   'life',
#   'mylong',
#   'term',
#   'albeit',
#   'somewhat',
#   'open_relationship',
#   'status',
#   'haschanged',
#   'consider',
#   'creative',
#   'artist',
#   'yet',
#   'someone',
#   'uses',
#   'lobes',
#   'originally_midwest',
#   'moved',
#   'years_ago',
#   'found',
#   'myhome',
#   'people',
#   'worked',
#   'animation',
#   'modeling',
#   'many',
#   'yearsbut',
#   'prefer',
#   'art',
#   'tangible',
#   'make',
#   'sculpture',
#   'big',
#   'sculpture',
#   'mostly',
#   'metal',
#   'days',
#   'tend',
#   'think',
#   'food',
#   'terms',
#   'ofcolor',
#   'like',
#   'way',
#   'sounds',
#   'look',
#   'feel',
#   'enjoy',
#   'life',
#   'valuespontaneity',
#   'gregarious',
#   'tangential',
#   'silly',
#   'analytical',
#   'andinspiring',
#   'burner',
#   'burningman',
#   'since',
#   'man',
#   'last',
#   'stood',
#   'theground',
#   'value',
#   'creativity',
#   'inspiration',
#   'music',
#   'andscience',
#   'sensuality',
#   'fun',
#   'entp',
#   'according',
#   'tomindtime',
#   'phenomenological',
#   'approach',
#   'thought',
#   'future',
#   'thinkerrather',
#   'past',
#   'present',
#   'thinker'],
#  ['really',
#   'simple',
#   'person',
#   'anaytical',
#   'personality',
#   'ilove',
#   'people',
#   'build',
#   'relationships',
#   'based',
#   'trust',
#   'work',
#   'quitea',
#   'bit',
#   'always',
#   'find',
#   'time',
#   'fun'],
#  ['pretty_much',
#   'cannot',
#   'bothered',
#   'fill',
#   'willsay',
#   'fun',
#   'warm',
#   'funny',
#   'active',
#   'yet',
#   'lazy',
#   'curious'],
#  ['pretty_laid',
#   'back',
#   'guy',
#   'currently',
#   'work_full',
#   'time',
#   'salesengineer',
#   'small',
#   'tech_startup',
#   'job',
#   'pretty',
#   'amazing',
#   'asi',
#   'lot',
#   'variety',
#   'day',
#   'day',
#   'activities',
#   'get',
#   'totravel',
#   'time',
#   'time',
#   'well',
#   'love_outdoors',
#   'beingvery',
#   'active',
#   'although',
#   'right_person',
#   'reallycare',
#   'enjoying',
#   'make',
#   'surethat',
#   'outside',
#   'grind',
#   'hobbies_include',
#   'playing',
#   'hockey',
#   'hanging_friends',
#   'traveling',
#   'cooking',
#   'poorly',
#   'hiking',
#   'andgoing',
#   'shows',
#   'pretty',
#   'sarcastic',
#   'person',
#   'definitely',
#   'clickwith',
#   'people',
#   'good_sense',
#   'humor',
#   'overlysensitive'],
#  ['might',
#   'wondering',
#   'profile_name',
#   'welli',
#   'love',
#   'burrito',
#   'kinds',
#   'burrito',
#   'cheesy',
#   'lamb',
#   'filled',
#   'veal',
#   'filled',
#   'duck',
#   'filled',
#   'whatever',
#   'care',
#   'give',
#   'agod',
#   'damn',
#   'burrito',
#   'seriously',
#   'though',
#   'love',
#   'food',
#   'inmy',
#   'mouth',
#   'like',
#   'cooking',
#   'waste_time',
#   'youlike',
#   'cooking_eating',
#   'gal',
#   'let',
#   'tell',
#   'hate',
#   'vegetarians',
#   'vegans',
#   'swhat',
#   'might',
#   'hottest',
#   'thing',
#   'since',
#   'marilyn',
#   'monroe',
#   'cow',
#   'put',
#   'said',
#   'cow',
#   'mouth',
#   'properlycooked',
#   'course',
#   'ride',
#   'said',
#   'cow',
#   'saidsunset',
#   'make_money',
#   'might',
#   'wondering',
#   'pay',
#   'allthis',
#   'tasty',
#   'tasty_food',
#   'one_word',
#   'murals',
#   'google',
#   'shit',
#   'youdon',
#   'know',
#   'actually',
#   'know',
#   'stop',
#   'readingthis',
#   'immediately',
#   'find',
#   'joe',
#   'shmoe',
#   'tno',
#   'joe',
#   'shmoe',
#   'paint',
#   'murals',
#   'need',
#   'mural',
#   'yourbedroom',
#   'public',
#   'bathroom',
#   'church',
#   'inside',
#   'dogshouse',
#   'problem',
#   'paint',
#   'went_school',
#   'zoo',
#   'keeping',
#   'zoology',
#   'fancy',
#   'folks',
#   'ended',
#   'paintingmurals',
#   'say',
#   'muhammad',
#   'gives',
#   'gift',
#   'gottarun',
#   'thanks',
#   'muhammad',
#   'thanks',
#   'whole',
#   'hell',
#   'alot',
#   'onto',
#   'things',
#   'like',
#   'fun',
#   'paragraphwhere',
#   'supposed',
#   'tell',
#   'obscure',
#   'music',
#   'andmovies',
#   'neither',
#   'never_heard',
#   'let',
#   'skipthat',
#   'bullshit',
#   'cut',
#   'right',
#   'chase',
#   'like',
#   'eat',
#   'food',
#   'drinkbeer',
#   'listen',
#   'really',
#   'popular',
#   'music',
#   'everyone',
#   'knows',
#   'everynow',
#   'like',
#   'watch_movie',
#   'film',
#   'youuptight',
#   'hipsters',
#   'want_meet',
#   'anyway',
#   'also',
#   'think',
#   'mylittle',
#   'pony',
#   'great',
#   'way',
#   'pass',
#   'time',
#   'saturdayafternoon',
#   'end'],
#  ['east_bay',
#   'native',
#   'big',
#   'time',
#   'nerd',
#   'highly',
#   'analytical',
#   'hedonistictendencies',
#   'expert',
#   'fields',
#   'cognitive',
#   'dissonance',
#   'language',
#   'andcomputer',
#   'programming',
#   'scuba',
#   'certified',
#   'startup',
#   'founder',
#   'open_source',
#   'contributor',
#   'probably',
#   'laid_back',
#   'person',
#   'ofall',
#   'time'],
#  ['hey',
#   'healthy',
#   'guy',
#   'health',
#   'everything',
#   'possible',
#   'love',
#   'run',
#   'workout',
#   'hike',
#   'regularly',
#   'aminto',
#   'physical_activities',
#   'well',
#   'love',
#   'hang',
#   'andbe',
#   'spontaneous'],
#  ['laid_back', 'guy', 'hoping_meet', 'really', 'nice', 'ladies'],
#  ['tom',
#   'tall',
#   'tom',
#   'funny',
#   'tom',
#   'creative',
#   'bright',
#   'tom',
#   'isloyal',
#   'dependable',
#   'loving',
#   'tom',
#   'good',
#   'job',
#   'drives',
#   'himcrazy',
#   'tom',
#   'cheat',
#   'tom',
#   'real',
#   'quiet',
#   'timesbut',
#   'let',
#   'freak',
#   'way',
#   'tom',
#   'works',
#   'atv',
#   'station',
#   'plays',
#   'bass',
#   'rock_band',
#   'tom',
#   'lot',
#   'offree',
#   'time',
#   'throwing',
#   'internet',
#   'see',
#   'hecan',
#   'meet_someone',
#   'special_share',
#   'life'],
#  ['born_raised',
#   'socal',
#   'moved_bay',
#   'area',
#   'forschool',
#   'kind',
#   'stuck',
#   'around',
#   'love',
#   'socal',
#   'thebay',
#   'grew',
#   'haha',
#   'visual_artist',
#   'currentlyworking',
#   'dreamworks',
#   'animation',
#   'pixar',
#   'toystory',
#   'haha',
#   'generally',
#   'positive',
#   'good_humored',
#   'guy',
#   'try',
#   'athleticas',
#   'possible',
#   'enjoy',
#   'taking',
#   'swings',
#   'batting',
#   'cages',
#   'snowboarding',
#   'wake_boarding',
#   'send_message',
#   'want_know',
#   'try',
#   'respondthough',
#   'sometimes_forget',
#   'check',
#   'messages',
#   'sorry',
#   'inadvance',
#   'hear',
#   'back',
#   'right_away'],
#  ['born_raised',
#   'rural',
#   'missouri',
#   'educated',
#   'boston',
#   'andbaltimore',
#   'love',
#   'open_spaces',
#   'urban',
#   'places',
#   'speakwith',
#   'twang',
#   'anymore',
#   'except',
#   'back',
#   'home',
#   'notintentional',
#   'swear',
#   'unusually',
#   'high',
#   'tolerance',
#   'perhapseven',
#   'appreciation',
#   'country',
#   'music',
#   'itunes',
#   'collectionspans',
#   'musical',
#   'spectrum',
#   'politically_liberal',
#   'highschool',
#   'classmate',
#   'postings',
#   'sometimes',
#   'make',
#   'cringe',
#   'iunderstand',
#   'good',
#   'people',
#   'huge_fan',
#   'rei',
#   'iavoid',
#   'shopping',
#   'wal',
#   'mart',
#   'seen',
#   'smalltown',
#   'economy',
#   'prefer',
#   'take',
#   'subaru',
#   'dirtroads',
#   'learned',
#   'love',
#   'challenge',
#   'squeezing',
#   'theonly',
#   'available',
#   'parallel',
#   'parking',
#   'space',
#   'moved_bay',
#   'area',
#   'nine_years',
#   'ago',
#   'start',
#   'first',
#   'real',
#   'job',
#   'count',
#   'high_school',
#   'summer',
#   'grill',
#   'boy',
#   'atmcdonald',
#   'mentoring',
#   'graduate',
#   'students',
#   'lab',
#   'orteaching',
#   'classroom',
#   'enjoy',
#   'outdoorshiking',
#   'biking',
#   'fly_fishing',
#   'skiing',
#   'hanging',
#   'dog',
#   'ilove',
#   'watching_films',
#   'going_concerts',
#   'plays',
#   'keeping_fit',
#   'byrunning',
#   'road',
#   'races',
#   'sixteen',
#   'half_marathons',
#   'far',
#   'enjoy',
#   'goodfood',
#   'wine',
#   'cherish',
#   'good_conversation',
#   'try',
#   'read',
#   'much_asi',
#   'though',
#   'sometimes',
#   'best',
#   'intentions',
#   'limited',
#   'aquick',
#   'excursion',
#   'new_yorker',
#   'whatever',
#   'displayin',
#   'grocery_store',
#   'aisle',
#   'handed',
#   'mysister',
#   'roland',
#   'brushing',
#   'piano',
#   'playing',
#   'alsolike',
#   'cook',
#   'others',
#   'especially'],
#  ['okay',
#   'know',
#   'checked',
#   'pictures',
#   'back',
#   'formore',
#   'great',
#   'going',
#   'take',
#   'dog',
#   'walk',
#   'findout',
#   'little',
#   'enjoy',
#   'shoot_message',
#   'orwink',
#   'whatever',
#   'done',
#   'get_know',
#   'eachother',
#   'want',
#   'laugh_loud',
#   'come',
#   'meet',
#   'jokes',
#   'set',
#   'yourolling',
#   'floor',
#   'eyes',
#   'legs',
#   'make',
#   'stand',
#   'whatfollows',
#   'list',
#   'smile',
#   'set',
#   'everything',
#   'even',
#   'yourmood'],
#  ['socially_awkward',
#   'give',
#   'drinks',
#   'think',
#   'havea',
#   'good',
#   'laugh',
#   'hate',
#   'read_profiles',
#   'feels_like',
#   'havebeen',
#   'copied',
#   'paste',
#   'either',
#   'read',
#   'one',
#   'many',
#   'thesame',
#   'ones',
#   'recently',
#   'joined',
#   'meet',
#   'crew',
#   'going',
#   'try',
#   'afew',
#   'mixer',
#   'running',
#   'group',
#   'hopefully_meet',
#   'newfaces',
#   'friends',
#   'fate',
#   'pushing',
#   'trying',
#   'pretty',
#   'goodstart',
#   'let_start',
#   'really',
#   'expect',
#   'toread',
#   'whole',
#   'profile',
#   'got',
#   'far',
#   'kudos',
#   'handclap'],
#  ['way',
#   'los_angeles',
#   'portland',
#   'landed',
#   'sanfrancisco',
#   'cold',
#   'heading',
#   'san_diego',
#   'nextweek',
#   'update',
#   'back',
#   'san_francisco',
#   'seem',
#   'get',
#   'away'],
#  ['really',
#   'point',
#   'summary',
#   'think',
#   'anyoneactually',
#   'reads',
#   'part',
#   'look',
#   'pictures',
#   'either',
#   'move',
#   'think',
#   'cute',
#   'enough',
#   'read',
#   'myemail',
#   'return',
#   'message',
#   'viewing',
#   'pics',
#   'see',
#   'ifi',
#   'cute',
#   'enough',
#   'come',
#   'know',
#   'truth',
#   'guys',
#   'generally',
#   'put_effort',
#   'online',
#   'becauseit',
#   'goes',
#   'nowhere',
#   'sure',
#   'could',
#   'talk',
#   'funny',
#   'smarti',
#   'amazing',
#   'little',
#   'boy',
#   'truly',
#   'taught',
#   'meabout',
#   'unconditional_love',
#   'running',
#   'clear',
#   'mind',
#   'eat',
#   'hole_wall',
#   'places',
#   'come',
#   'new',
#   'get',
#   'richscheme',
#   'every',
#   'days',
#   'obviously',
#   'still',
#   'trying_find',
#   'one',
#   'could',
#   'get',
#   'ways',
#   'would',
#   'lucky',
#   'guy',
#   'likeme',
#   'care',
#   'thepics',
#   'always',
#   'forget',
#   'arrogance',
#   'new',
#   'trait',
#   'among',
#   'many',
#   'onthis_site',
#   'look',
#   'guys',
#   'think',
#   'yourso',
#   'pretty',
#   'wear',
#   'nice',
#   'clothes',
#   'deserve',
#   'looking',
#   'guy',
#   'thought',
#   'cute',
#   'actually',
#   'read',
#   'thispoint',
#   'high',
#   'five',
#   'wrote',
#   'test',
#   'see',
#   'girlsactually',
#   'read_profiles',
#   'think',
#   'cute',
#   'butread',
#   'far',
#   'well',
#   'tricked',
#   'probably',
#   'thatinterested',
#   'anyways',
#   'yes',
#   'agree',
#   'equally',
#   'appliesto',
#   'guys',
#   'fact',
#   'guys',
#   'worse',
#   'yes',
#   'meant',
#   'beslightly',
#   'truthful',
#   'humorous',
#   'since',
#   'pictures',
#   'make',
#   'decision',
#   'read_profile',
#   'really',
#   'looking_forwardto',
#   'seeing',
#   'kind',
#   'hate',
#   'mail',
#   'going',
#   'get',
#   'coursekeep',
#   'updated'],
#  ['great',
#   'running',
#   'order',
#   'new',
#   'tires',
#   'good',
#   'brakes',
#   'smogged',
#   'through2011',
#   'paint',
#   'decent',
#   'shape',
#   'engine',
#   'tip',
#   'top',
#   'theupholstery',
#   'may',
#   'need',
#   'replaced'],
#  ['human',
#   'male',
#   'ten',
#   'fingers',
#   'ten',
#   'toes',
#   'forthe',
#   'foreseeable',
#   'future',
#   'hair',
#   'points',
#   'interest',
#   'include',
#   'ability',
# ...
#   'giving',
#   'affectionespecially',
#   'woman',
#   'older',
#   'way',
#   'older',
#   'yes',
#   'older',
#   'woman',
#   'younger',
#   'man',
#   'always',
#   'foundmyself',
#   'good',
#   'exposing',
#   'juvenile',
#   'years',
#   'get',
#   'adefinite',
#   'personality',
#   'complete',
#   'quirks',
#   'idiosyncrasies',
#   'nothing',
#   'rather',
#   'reveal',
#   'mine',
#   'discoveryours',
#   'let',
#   'get',
#   'really',
#   'silly',
#   'sometimes',
#   'make',
#   'allworthwhile',
#   'also',
#   'great',
#   'patience',
#   'take',
#   'slow',
#   'andreally',
#   'slow',
#   'stretched',
#   'years',
#   'typically',
#   'prefer'],
#  ['curious',
#   'smart',
#   'individualistic',
#   'intellectual',
#   'active',
#   'andprincipled',
#   'dry_sense',
#   'humor',
#   'appreciation',
#   'theabsurd'],
#  ['moved',
#   'years_ago',
#   'way',
#   'boston',
#   'like',
#   'vinyl',
#   'art',
#   'wine',
#   'movies',
#   'comics',
#   'digital_art',
#   'yerba',
#   'matte',
#   'tea',
#   'hateon',
#   'things',
#   'enjoy',
#   'retrospect',
#   'rather',
#   'listento',
#   'others',
#   'talk',
#   'also',
#   'like',
#   'animals'],
#  ['quick',
#   'overview',
#   'moved_oakland',
#   'almost_years',
#   'ago',
#   'tallahassee',
#   'welsh',
#   'corgi',
#   'named',
#   'science',
#   'tend',
#   'make',
#   'art',
#   'consume',
#   'ever',
#   'dancing',
#   'cause',
#   'time',
#   'think',
#   'musicisterrible',
#   'say',
#   'dance',
#   'favoritebands',
#   'love',
#   'cooking',
#   'except',
#   'really',
#   'would_like',
#   'people',
#   'hang',
#   'way',
#   'hardertomake',
#   'friends',
#   'late_20s',
#   'outside',
#   'college',
#   'townthere',
#   'save',
#   'later'],
#  ['midwestern',
#   'boy',
#   'design',
#   'although',
#   'like',
#   'football',
#   'nascar',
#   'football',
#   'chewing',
#   'tabacco',
#   'souping',
#   'truck',
#   'ordrinking',
#   'beer',
#   'got',
#   'hell',
#   'outof',
#   'fast',
#   'possible',
#   'since',
#   'leaving',
#   'lived',
#   'mexico',
#   'peru',
#   'spain',
#   'texas',
#   'oregon',
#   'finally',
#   'bay_area',
#   'since_moving',
#   'started',
#   'profit',
#   'play',
#   'lot',
#   'ofmusic',
#   'matter_fact',
#   'two',
#   'intertwined',
#   'also',
#   'volunteer',
#   'fora',
#   'local',
#   'college',
#   'radio_station',
#   'crazy',
#   'busy',
#   'majorbeliever',
#   'collective',
#   'environments',
#   'makes',
#   'dopey',
#   'grin',
#   'surfing',
#   'camping',
#   'old',
#   'time',
#   'slang',
#   'music',
#   'psychedelics',
#   'collecting',
#   'oldhauntedfurniture',
#   'records',
#   'books',
#   'taxidermy',
#   'food',
#   'getting_dirty',
#   'silent',
#   'classic',
#   'badmovies',
#   'stanford',
#   'theatre',
#   'flea',
#   'farmers_markets',
#   'selfsufficient',
#   'living',
#   'alot',
#   'crapisn',
#   'kind',
#   'weird',
#   'okcupid',
#   'asks',
#   'income',
#   'levels',
#   'think',
#   'favorite',
#   'part',
#   'filling_profile',
#   'mnot',
#   'filling',
#   'anymore'],
#  ['let',
#   'put',
#   'smoking',
#   'jacket',
#   'head',
#   'den',
#   'brandysnifting',
#   'ahhh',
#   'yes',
#   'like',
#   'lapel',
#   'yes',
#   'pureguatamalan',
#   'rainforestchipmunk',
#   'follow',
#   'way',
#   'less',
#   'want',
#   'hearmore',
#   'lexicographer',
#   'etc',
#   'stuff'],
#  ['recently_moved',
#   'north_bay',
#   'exploring',
#   'loving',
#   'area',
#   'musically_inclined',
#   'love',
#   'arts',
#   'general',
#   'good_food',
#   'obscure',
#   'aspects_life',
#   'always',
#   'intriguing'],
#  ['say',
#   'hailing',
#   'texas',
#   'longhorns',
#   'icame',
#   'cali',
#   'well',
#   'decade',
#   'ago',
#   'looking',
#   'little',
#   'sunshinein',
#   'life',
#   'definitely',
#   'understand',
#   'people',
#   'come',
#   'tocalifornia',
#   'never',
#   'leave',
#   'like',
#   'well',
#   'always',
#   'liked',
#   'cook',
#   'mostly',
#   'southindian',
#   'comfort',
#   'food',
#   'read',
#   'love',
#   'amazon',
#   'kindle',
#   'ipad',
#   'listen_music',
#   'like',
#   'something',
#   'time',
#   'gamble',
#   'really',
#   'bet',
#   'addiction',
#   'watch_movies',
#   'favorite_hobby',
#   'call',
#   'travel',
#   'loveto_travel',
#   'far',
#   'places',
#   'meet_new',
#   'people',
#   'wherever',
#   'traveling',
#   'lets',
#   'practice',
#   'another',
#   'favorite_hobby',
#   'photography',
#   'anything',
#   'though',
#   'love',
#   'hanging_friends',
#   'even',
#   'anything',
#   'particular',
#   'like',
#   'well',
#   'think',
#   'one_word',
#   'describes',
#   'bestis',
#   'happy',
#   'coincidentally',
#   'also',
#   'name',
#   'cantranslate',
#   'one',
#   'indian',
#   'languages',
#   'like',
#   'fun',
#   'love',
#   'laugh',
#   'attitude',
#   'life',
#   'pretty_easy',
#   'going',
#   'malso',
#   'apparently',
#   'parenthetical',
#   'profile',
#   'butconversationally',
#   'also',
#   'know',
#   'need',
#   'stop',
#   'looking_someone',
#   'first_foremost',
#   'lookingfor',
#   'friend',
#   'strong_believer',
#   'friendship',
#   'first_sight',
#   'said',
#   'favorite',
#   'people',
#   'open_minded',
#   'well_versed',
#   'inthe',
#   'art',
#   'conversation',
#   'intelligent',
#   'caring',
#   'fun',
#   'love_travel',
#   'borrow',
#   'phrase',
#   'friend_mine',
#   'know',
#   'good',
#   'way',
#   'towaste',
#   'afternoon'],
#  ['friend',
#   'called',
#   'cross',
#   'aziz',
#   'ansari',
#   'steve',
#   'jobs',
#   'maybe',
#   'teensy',
#   'stretch',
#   'take',
#   'bit',
#   'year',
#   'moved',
#   'toronto',
#   'dig',
#   'westcoast',
#   'vibe',
#   'amazing',
#   'food',
#   'coffee',
#   'miss',
#   'big',
#   'city',
#   'hustlesometimes',
#   'want',
#   'one_thing',
#   'girl',
#   'effortless',
#   'conversation',
#   'feellike',
#   'connect',
#   'everything_else',
#   'easy'],
#  ['guy',
#   'sitting',
#   'cushy',
#   'bench',
#   'bookstore',
#   'reading',
#   'onthe',
#   'road',
#   'hours',
#   'dear',
#   'friends',
#   'bookstore',
#   'peace',
#   'brothers',
#   'also',
#   'guy',
#   'walking',
#   'mission',
#   'streetpretty',
#   'much',
#   'shouting',
#   'friend',
#   'camera',
#   'work',
#   'earlyperiod',
#   'fellini',
#   'could',
#   'think',
#   'average',
#   'nerd',
#   'thepark',
#   'except',
#   'intellectualbuzz',
#   'one_thing',
#   'funny',
#   'observant',
#   'little_bit',
#   'nuts',
#   'havea',
#   'trenchant',
#   'wit',
#   'plenty',
#   'skepticism',
#   'towards',
#   'people',
#   'power',
#   'afabulist',
#   'idealist',
#   'cynic',
#   'usually',
#   'time',
#   'love',
#   'take',
#   'different',
#   'ideas',
#   'put',
#   'one',
#   'basket',
#   'mixing',
#   'art',
#   'politics_science',
#   'imagination',
#   'tradition',
#   'withcuriosity',
#   'progress',
#   'change',
#   'also',
#   'stunned',
#   'silence',
#   'grateful',
#   'forthat',
#   'rodin',
#   'sculpture',
#   'ancient',
#   'tree',
#   'redwoodforest',
#   'incredible',
#   'solo',
#   'legendary',
#   'jazz',
#   'bassist',
#   'sometimes',
#   'get_lost',
#   'big_picture',
#   'world',
#   'ideas',
#   'snapsup',
#   'attention',
#   'like',
#   'flashy',
#   'lure',
#   'need',
#   'reminder',
#   'thatdetails',
#   'matter',
#   'story',
#   'called',
#   'style',
#   'born',
#   'reader',
#   'terrific',
#   'listener',
#   'things',
#   'aliving',
#   'write_poetry',
#   'philosophical',
#   'fiction',
#   'livedabroad',
#   'else',
#   'npr',
#   'junkie',
#   'avoice',
#   'crush',
#   'terry',
#   'gross',
#   'excellent',
#   'cook',
#   'thebattle',
#   'scars',
#   'prove',
#   'every',
#   'page',
#   'cookbook',
#   'splatteredwith',
#   'something',
#   'kind',
#   'animals',
#   'doubt',
#   'err',
#   'onthe',
#   'side',
#   'reality',
#   'humble',
#   'necessity',
#   'mayhave',
#   'architectonic',
#   'notions',
#   'meaning',
#   'history',
#   'yet',
#   'takethe',
#   'bus',
#   'love',
#   'america',
#   'flannery',
#   'connor',
#   'edward',
#   'hopper',
#   'tom_waits',
#   'also',
#   'new',
#   'city',
#   'work_progress'],
#  ['easy_going',
#   'hard_working',
#   'person',
#   'still',
#   'finds',
#   'time',
#   'afterwork',
#   'smoke',
#   'little',
#   'drink',
#   'couple',
#   'beers',
#   'know',
#   'thatjust',
#   'single',
#   'get',
#   'old',
#   'eventually',
#   'somesay',
#   'already',
#   'point',
#   'thinking',
#   'aboutsettling',
#   'total',
#   'relationships',
#   'life',
#   'inever',
#   'felt',
#   'important',
#   'like',
#   'honestly',
#   'lost',
#   'virginitybecause',
#   'friends',
#   'made',
#   'seem',
#   'like',
#   'big_deal',
#   'justpulled',
#   'female',
#   'yeah',
#   'get',
#   'way'],
#  ['laid_back',
#   'person',
#   'part',
#   'might',
#   'say',
#   'amincapable',
#   'stressing',
#   'kind_nerd',
#   'even_though',
#   'oneexpects'],
#  ['maia', 'john', 'couple', 'looking', 'new', 'friendsto', 'hang'],
#  ['bay_area',
#   'native',
#   'spent',
#   'entire',
#   'live',
#   'living',
#   'exceptfor',
#   'year',
#   'grad_school',
#   'outdoors',
#   'type',
#   'asi',
#   'like',
#   'play_golf',
#   'weekends',
#   'jogging',
#   'around',
#   'thelake',
#   'trying_find',
#   'special_someone',
#   'life',
#   'willingto',
#   'give',
#   'site',
#   'try',
#   'lose'],
#  ['difficult_describe',
#   'identity',
#   'tstatic',
#   'flexible',
#   'adaptable',
#   'circumstance',
#   'professional',
#   'personal',
#   'work',
#   'process',
#   'somestrengths',
#   'pretty',
#   'bright',
#   'creative',
#   'willing',
#   'take_risks',
#   'see',
#   'things_differently',
#   'people',
#   'though',
#   'canappreciate',
#   'range',
#   'perspectives',
#   'weaknesses',
#   'tendto',
#   'loyal_fault',
#   'good',
#   'getting',
#   'need',
#   'wantin',
#   'relationships'],
#  ['sea',
#   'till',
#   'july',
#   'bit',
#   'type_guy',
#   'legitimately',
#   'enjoys',
#   'company',
#   'women',
#   'open_doors',
#   'pull',
#   'chairs',
#   'pay',
#   'dinner',
#   'things',
#   'dexpect',
#   'pretty',
#   'old_school',
#   'knowi',
#   'traveler',
#   'countries',
#   'last_years',
#   'whichis',
#   'mainly',
#   'result',
#   'year',
#   'school',
#   'traveled',
#   'western_europe',
#   'vagabond',
#   'style',
#   'hope',
#   'make',
#   'australia',
#   'next',
#   'havethe',
#   'best',
#   'accent',
#   'ever',
#   'favorite_color',
#   'blue',
#   'awesome',
#   'pair',
#   'bluesuede',
#   'shoes',
#   'need',
#   'least',
#   'spontaneous',
#   'adventure',
#   'point',
#   'time',
#   'one_favorite',
#   'things',
#   'head',
#   'bike',
#   'makesome',
#   'random',
#   'turns',
#   'always',
#   'end',
#   'meeting_new',
#   'people',
#   'findsomething',
#   'fun',
#   'jumped',
#   'foot',
#   'cliff',
#   'intowater',
#   'hiked',
#   'miles',
#   'one_day',
#   'biked',
#   'miles',
#   'one_day',
#   'sailed',
#   'across',
#   'pacific',
#   'like',
#   'kinds',
#   'thingsnot',
#   'really',
#   'sure',
#   'kind',
#   'girl',
#   'would',
#   'want',
#   'life',
#   'thispoint',
#   'even',
#   'want',
#   'one',
#   'getting',
#   'ialready',
#   'found',
#   'girl',
#   'could',
#   'make',
#   'iteasier',
#   'descriptive',
#   'words',
#   'spontaneous_adventurous',
#   'romantic',
#   'positive',
#   'confident',
#   'funny',
#   'intellectual',
#   'honest',
#   'outgoing',
#   'joke',
#   'bear',
#   'walks',
#   'bar',
#   'says',
#   'want',
#   'bourbonand',
#   'coke',
#   'bartender',
#   'asks',
#   'huge',
#   'pause',
#   'bear',
#   'says',
#   'life',
#   'yes',
#   'know',
#   'want',
#   'lol',
#   'blame'],
#  ['short',
#   'like',
#   'math',
#   'psychology',
#   'dancing',
#   'sharingmusic',
#   'climbing',
#   'growth',
#   'mindset',
#   'getting',
#   'bottom',
#   'disagreements',
#   'empirical',
#   'matters',
#   'flippant',
#   'ridiculous',
#   'nonsense',
#   'understanding',
#   'values',
#   'emotionsof',
#   'people',
#   'around',
#   'long',
#   'talks',
#   'outdoors',
#   'especially',
#   'conversation',
#   'eithergoes',
#   'somewhere',
#   'happens',
#   'tree',
#   'necessarily',
#   'yes',
#   'necessarily',
#   'enfj',
#   'takes',
#   'taking',
#   'things',
#   'tooseriously',
#   'pretty',
#   'seriously_except',
#   'disagree',
#   'normatively',
#   'thef',
#   'axis',
#   'ask',
#   'favorite',
#   'people',
#   'cantransition',
#   'seamlessly',
#   'intellectual',
#   'flippantridiculous',
#   'nonsense',
#   'climbing',
#   'library',
#   'sideways',
#   'alsoreally',
#   'like',
#   'people',
#   'find',
#   'happiness',
#   'others',
#   'contagious',
#   'happy',
#   'want',
#   'show',
#   'damn',
#   'long',
#   'grew',
#   'canada',
#   'looking',
#   'back',
#   'pretty',
#   'trippy',
#   'roughly',
#   'half',
#   'meat',
#   'ate',
#   'stuff',
#   'family',
#   'fished',
#   'andhunted',
#   'built',
#   'house',
#   'trees',
#   'dad',
#   'cut',
#   'downand',
#   'pulled',
#   'forest',
#   'sawed',
#   'saw',
#   'mill',
#   'builtwith',
#   'grandfather',
#   'okay',
#   'womb',
#   'momhelped',
#   'child',
#   'played',
#   'ice_hockey',
#   'frozen',
#   'atlanticharbor',
#   'front',
#   'house',
#   'kids',
#   'village',
#   'onthe_weekends',
#   'ice',
#   'fish',
#   'make',
#   'huts',
#   'tree',
#   'branches',
#   'tosleep',
#   'stay',
#   'warm',
#   'slow',
#   'burning',
#   'fire',
#   'tdestroy',
#   'hut',
#   'live',
#   'california',
#   'love',
#   'also',
#   'lived',
#   'rome',
#   'forsix',
#   'months',
#   'awesome',
#   'bay',
#   'wins',
#   'still',
#   'going',
#   'backto',
#   'visit',
#   'canada',
#   'twice',
#   'year',
#   'pretty',
#   'fun',
#   'canadian',
#   'hasthe',
#   'desirable',
#   'side',
#   'effect',
#   'whoever',
#   'marries',
#   'gets',
#   'freeuniversal',
#   'health_care',
#   'handy',
#   'old',
#   'used_play',
#   'lot',
#   'musical_instruments',
#   'handinjury',
#   'never',
#   'got_back',
#   'hours_day',
#   'serious',
#   'mydefault',
#   'passive',
#   'experience',
#   'music',
#   'still',
#   'revise',
#   'andmentally',
#   'interject',
#   'parts',
#   'though',
#   'makes',
#   'listening',
#   'fun',
#   'far',
#   'beliefs',
#   'let',
#   'wax',
#   'earnest',
#   'two',
#   'paragraphs',
#   'ibelieve',
#   'physical',
#   'world',
#   'things',
#   'amenable',
#   'scientificstudy',
#   'find',
#   'boring',
#   'unromantic',
#   'find',
#   'itbeautiful',
#   'would',
#   'believe',
#   'might',
#   'questionsabout',
#   'human',
#   'soul',
#   'people',
#   'wrong',
#   'well',
#   'thereare',
#   'good',
#   'news',
#   'soul',
#   'source',
#   'seat',
#   'humanwill',
#   'conscience',
#   'morality',
#   'thought',
#   'emotion',
#   'really',
#   'doesexist',
#   'found',
#   'bad',
#   'news',
#   'immortal',
#   'butthere',
#   'good',
#   'news',
#   'made',
#   'neurons',
#   'far',
#   'cantell',
#   'runs',
#   'physics',
#   'magic',
#   'yep',
#   'soul',
#   'regularmatter',
#   'think',
#   'pretty_awesome',
#   'course',
#   'science',
#   'could',
#   'wrong',
#   'themost',
#   'reliable',
#   'procedure',
#   'forming',
#   'accurate',
#   'beliefs',
#   'anybelief',
#   'forming',
#   'tradition',
#   'unlikely',
#   'far',
#   'cantell',
#   'different',
#   'truths',
#   'world',
#   'works',
#   'fordifferent',
#   'people',
#   'one',
#   'staring',
#   'ithink',
#   'cozy',
#   'like',
#   'sitting_around',
#   'campfire',
#   'means',
#   'canstrive',
#   'together',
#   'species',
#   'find',
#   'objectively',
#   'increasinglyaccurate',
#   'view',
#   'things',
#   'work',
#   'ever',
#   'thought',
#   'thataccepting',
#   'falsehoods',
#   'way',
#   'people',
#   'tolerant',
#   'ofeach',
#   'beliefs',
#   'patience',
#   'diligence',
#   'reall',
#   'wrong',
#   'tons',
#   'stuff',
#   'let',
#   'compare',
#   'notes',
#   'get',
#   'itright',
#   'join',
#   'campfire',
#   'let',
#   'dance_party',
#   'radio',
#   'like',
#   'hating',
#   'pop_culture',
#   'outof',
#   'style',
#   'seriously',
#   'need',
#   'dancing'],
#  ['bay_area',
#   'native',
#   'recent',
#   'resident',
#   'college_grad',
#   'nerd',
#   'formercopy',
#   'editor',
#   'feminist',
#   'poor',
#   'typist',
#   'dangerous',
#   'amateur',
#   'rapper'],
#  ['construction',
#   'good',
#   'idea',
#   'time',
#   'mnot',
#   'tech_savvy',
#   'like',
#   'food',
#   'eat',
#   'withyour',
#   'hands',
#   'like',
#   'graff',
#   'writers',
#   'mess',
#   'city',
#   'havegood',
#   'potential',
#   'energy',
#   'like',
#   'high',
#   'end',
#   'clothing',
#   'saysabout',
#   'day',
#   'age',
#   'live',
#   'womans',
#   'dress',
#   'form',
#   'playwith',
#   'time',
#   'time',
#   'movies',
#   'every',
#   'toconcerts',
#   'every',
#   'like',
#   'dub',
#   'electro',
#   'house',
#   'andhardcore',
#   'hip_hop',
#   'wordsmith',
#   'given_moment',
#   'likecoining',
#   'phrases',
#   'right',
#   'word',
#   'eludes',
#   'like',
#   'dance',
#   'laugh',
#   'time',
#   'usually',
#   'means',
#   'agood_time',
#   'really',
#   'working',
#   'like',
#   'mean',
#   'fore',
#   'play',
#   'andmaybe',
#   'learning',
#   'sex',
#   'laugh',
#   'partner',
#   'enjoy',
#   'hookah',
#   'bars',
#   'laughing',
#   'like',
#   'messing',
#   'clean',
#   'upwhile',
#   'laughing',
#   'would_like',
#   'think',
#   'decent',
#   'artist',
#   'mixmedia',
#   'working',
#   'wood',
#   'moment',
#   'going',
#   'great',
#   'film_maker',
#   'one_day',
#   'mantra',
#   'everand',
#   'day',
#   'ahhh',
#   'else',
#   'west',
#   'african',
#   'dance',
#   'falls',
#   'dance',
#   'like',
#   'cook',
#   'orbe',
#   'helpful',
#   'kitchen',
#   'general',
#   'like',
#   'falling_asleep',
#   'awoman',
#   'happy',
#   'fall_asleep',
#   'druel',
#   'pillows',
#   'sometimes',
#   'known',
#   'snore',
#   'andlook',
#   'work',
#   'things',
#   'get',
#   'tuff',
#   'think',
#   'going',
#   'let',
#   'hairgrown',
#   'late',
#   'water',
#   'snacks'],
#  ['graduated_berkeley',
#   'currently',
#   'med_school',
#   'love',
#   'adventureand',
#   'novelty',
#   'happy',
#   'balanced',
#   'dont',
#   'enough',
#   'time',
#   'getout',
#   'meet',
#   'people',
#   'sooooo',
#   'ladies',
#   'gentle'],
#  ...]

# %%
dictionary = Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
ldamodel = LdaModel(corpus=corpus, num_topics=16, id2word=dictionary)

# %%
tf_vectorizer = CountVectorizer(max_features=1000, stop_words='english')
print("Vectorizing text by word counts...")
tf_text = tf_vectorizer.fit_transform(df_sp['spacified'])
tmp = tf_text.get_shape()
print("Our transformed text has", tmp[0], "rows and", tmp[1], "columns.")

# %%
ntopics = 16
#how many top words we want to display for each topic
nshow = 20

# %%
model = LatentDirichletAllocation(n_components=ntopics, max_iter=10, 
                                  learning_method='online', n_jobs=-1)

print('Performing LDA on vectors. This may take a while...')
lda = model.fit(tf_text)
lda_topics = lda.components_

print('Done!')

# %%
pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)

# %%
#Find the number of topics for LDA with the most coherence
c_v = []
limit = range(1, 25)
for num_topics in limit:
    lm = LdaModel(corpus=corpus, num_topics=num_topics,
                  id2word=dictionary)
    cm = CoherenceModel(model=lm, texts=texts, dictionary=dictionary,
                       coherence='c_v')
    c_v.append(cm.get_coherence())

# %%
##Find the number of topics for LDA with the most coherence
c_v_lsi = []
limit = range(1, 25)
for num_topics in limit:
    ls = LsiModel(corpus=corpus, num_topics=num_topics,
                  id2word=dictionary)
    cm = CoherenceModel(model=ls, texts=texts, dictionary=dictionary,
                       coherence='c_v')
    c_v_lsi.append(cm.get_coherence())

# %%
c_v_hdp = []
limit = range(1, 25)
for num_topics in limit:
    hm = HdpModel(corpus=corpus, num_topics=num_topics,
                  id2word=dictionary)
    cm = CoherenceModel(model=hm, texts=texts, dictionary=dictionary,
                       coherence='c_v')
    c_v_hdp.append(cm.get_coherence())
